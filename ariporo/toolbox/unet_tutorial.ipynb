# %% [markdown]
# Step 1 : Patch Extraction

# %%
import os
import numpy as np
import tifffile as tiff
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, BatchNormalization, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import rasterio
from rasterio.mask import mask
from rasterio.transform import from_origin
import geopandas as gpd
import cv2
import random
import pandas as pd

# %%
def extract_patches(image_path, label_path, shapefile_path, output_dir, train_ratio=0.5, val_ratio=0.25, test_ratio=0.25):
    
    with rasterio.open(image_path) as src_img:
        
        with rasterio.open(label_path) as src_lbl:
            
            grid = gpd.read_file(shapefile_path) #Load the satellite image, load the labels, and then the grid containing the patches. 
            
            train_img_dir = os.path.join(output_dir, 'train/images')
            val_img_dir = os.path.join(output_dir, 'validation/images')
            test_img_dir = os.path.join(output_dir, 'test/images')

            train_lbl_dir = os.path.join(output_dir, 'train/labels')
            val_lbl_dir = os.path.join(output_dir, 'validation/labels')
            test_lbl_dir = os.path.join(output_dir, 'test/labels')
            #Create the train, validation, and test directories if they do not already exist.
            
            for dir_path in [train_img_dir, val_img_dir, test_img_dir, train_lbl_dir, val_lbl_dir, test_lbl_dir]:
                if not os.path.exists(dir_path):
                    os.makedirs(dir_path)

            
            indices = list(grid.index)
            random.shuffle(indices)
            # Shuffle the patch indices for a random distribution
            
            num_patches = len(indices)
            
            #num_train = int(train_ratio * num_patches)
            #num_val = int(val_ratio * num_patches)
            #num_test = num_patches - num_train - num_val

            # Ensure we have at least 1 patch for each split
            num_train = max(1, int(train_ratio * num_patches))
            num_val = max(1, int(val_ratio * num_patches))
            num_test = max(1, num_patches - num_train - num_val)

            # Calculate the sizes of the train, validation, and test sets.
            
            train_indices = indices[:num_train]
            val_indices = indices[num_train:num_train + num_val]
            test_indices = indices[num_train + num_val:]

            
            def save_patch_and_label(patch, label, transform, output_img_subdir, output_lbl_subdir, patch_filename):
                
                patch_img_path = os.path.join(output_img_subdir, patch_filename)
                with rasterio.open(
                    patch_img_path, 'w',
                    driver='GTiff',
                    height=224, width=224,
                    count=4, dtype=patch.dtype, #Set the count variable according to the number of spectral bands you have.
                    crs=src_img.crs, transform=transform
                ) as dst_img:
                    dst_img.write(patch)
                print(f"Image patch {patch_filename} saved in {output_img_subdir}.")

                
                patch_lbl_path = os.path.join(output_lbl_subdir, patch_filename)
                with rasterio.open(
                    patch_lbl_path, 'w',
                    driver='GTiff',
                    height=224, width=224,
                    count=1, dtype=label.dtype,  # Single channel for labels
                    crs=src_lbl.crs, transform=transform
                ) as dst_lbl:
                    dst_lbl.write(label[0, :, :], 1)  # Correcting the write operation
                print(f"Label patch {patch_filename} saved in {output_lbl_subdir}.")

            
            for idx, row in grid.iterrows():
                geom = [row['geometry']]
                auto_value = row['AUTO']  # Column with unique identifiers

                # Extract the patch for the image
                patch_img, transform = mask(src_img, geom, crop=True)
                patch_lbl, _ = mask(src_lbl, geom, crop=True)

                # Check the patch size and resize if necessary (for the image and the label)
                height_img, width_img = patch_img.shape[1], patch_img.shape[2]
                height_lbl, width_lbl = patch_lbl.shape[1], patch_lbl.shape[2]
                
                if height_img != 224 or width_img != 224:
                    resized_patch_img = np.zeros((4, 224, 224), dtype=patch_img.dtype)
                    for i in range(4):
                        resized_patch_img[i] = cv2.resize(patch_img[i], (224, 224), interpolation=cv2.INTER_LINEAR)
                    patch_img = resized_patch_img
                
                if height_lbl != 224 or width_lbl != 224:
                    resized_patch_lbl = cv2.resize(patch_lbl[0], (224, 224), interpolation=cv2.INTER_NEAREST)
                    patch_lbl = resized_patch_lbl[np.newaxis, :, :]  # Add channel dimension
                
                # Determine the directory to save the patch
                patch_filename = f"patch_{auto_value}.tif"
                if idx in train_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, train_img_dir, train_lbl_dir, patch_filename)
                elif idx in val_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, val_img_dir, val_lbl_dir, patch_filename)
                elif idx in test_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, test_img_dir, test_lbl_dir, patch_filename)

    print("Patch and label extraction completed, and distribution performed.")

# %%
from rasterio.merge import merge
import glob

# List all raster files
tif_files = glob.glob('ariporo\data\input\s2_aoi')
src_files = [rasterio.open(fp) for fp in tif_files]

# Merge
mosaic, out_trans = merge(src_files)

# Copy metadata
out_meta = src_files[0].meta.copy()
out_meta.update({"driver": "GTiff",
                 "height": mosaic.shape[1],
                 "width": mosaic.shape[2],
                 "transform": out_trans})

with rasterio.open("merged_output.tif", "w", **out_meta) as dest:
    dest.write(mosaic)

# %%
image_path = "../data/input/image_s2.tif"
label_path = "../data/input/label.tif"
shapefile_path = "../data/input/grid_2240.shp"
output_dir = "../data/patch"
extract_patches(image_path, label_path, shapefile_path, output_dir)
# Out:
# Image patch patch_0.0.tif saved in ../data/patch\train/images.
# Label patch patch_0.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1.0.tif saved in ../data/patch\train/images.
# Label patch patch_1.0.tif saved in ../data/patch\train/labels.
# Image patch patch_2.0.tif saved in ../data/patch\validation/images.
# Label patch patch_2.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_3.0.tif saved in ../data/patch\test/images.
# Label patch patch_3.0.tif saved in ../data/patch\test/labels.
# Patch and label extraction completed, and distribution performed.

# %% [markdown]
# Step 2 : Images pre-processing

# %%
# Normalization
def normalize_img(img):
    return img / np.max(img)

# Function to read .tif files and convert them into tensors
def load_data(image_dir, mask_dir):
    images = []
    masks = []
    for img_file in os.listdir(image_dir):
        if img_file.endswith('.tif') or img_file.endswith('.tiff'):
            img_path = os.path.join(image_dir, img_file)
            mask_path = os.path.join(mask_dir, img_file)
            
            # Read images and masks
            img = tiff.imread(img_path).astype(np.float32)
            mask = tiff.imread(mask_path).astype(np.uint8)
            
            img = normalize_img(img)
            
            images.append(img)
            masks.append(mask)
    
    # Convert the lists into numpy arrays
    images = np.array(images)
    masks = np.array(masks)
    
    # Convert numpy arrays into tensors
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    masks = tf.convert_to_tensor(masks, dtype=tf.uint8)
    
    return images, masks

# %%
train_image_dir = '../data/patch/train/images'
train_mask_dir = '../data/patch/train/labels'
val_image_dir = '../data/patch/validation/images/'
val_mask_dir = '../data/patch/validation/labels'


# Load and transform the training data
train_images, train_masks = load_data(train_image_dir, train_mask_dir)
val_images, val_masks = load_data(val_image_dir, val_mask_dir)

print(f'Shape of training images: {train_images.shape}')
print(f'Shape of training labels: {train_masks.shape}')

# Check the pixel values of the images
print(f'Minimum and maximum values of the training images: {tf.reduce_min(train_images).numpy()}, {tf.reduce_max(train_images).numpy()}')
print(f'Minimum and maximum values of the training labels: {tf.reduce_min(train_masks).numpy()}, {tf.reduce_max(train_masks).numpy()}')

print(f'Minimum and maximum values of the validation images: {tf.reduce_min(val_images).numpy()}, {tf.reduce_max(val_images).numpy()}')
print(f'Minimum and maximum values of the validation labels: {tf.reduce_min(val_masks).numpy()}, {tf.reduce_max(val_masks).numpy()}')
# Out:
# Shape of training images: (2, 224, 224, 4)
# Shape of training labels: (2, 224, 224)
# Minimum and maximum values of the training images: 0.00029797377646900713, 1.0
# Minimum and maximum values of the training labels: 0, 5
# Minimum and maximum values of the validation images: 0.00012124151544412598, 1.0
# Minimum and maximum values of the validation labels: 0, 5

# %% [markdown]
# Step 3 : Train of the U-Net Model

# %%
def unet_advanced(input_shape, num_classes=6):
    inputs = Input(input_shape)
    
    # Encodeur
    conv1 = Conv2D(64, 3, padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, 3, padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.5)(pool1)

    conv2 = Conv2D(128, 3, padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, 3, padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.5)(pool2)
    
    conv3 = Conv2D(256, 3, padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, 3, padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)
    
    conv4 = Conv2D(512, 3, padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, 3, padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.5)(pool4)
    
    conv5 = Conv2D(1024, 3, padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, 3, padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)

    up6 = UpSampling2D(size=(2, 2))(conv5)
    merge6 = Concatenate()([conv4, up6])
    conv6 = Conv2D(512, 3, padding='same')(merge6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, 3, padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    merge7 = Concatenate()([conv3, up7])
    conv7 = Conv2D(256, 3, padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, 3, padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    merge8 = Concatenate()([conv2, up8])
    conv8 = Conv2D(128, 3, padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, 3, padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    
    up9 = UpSampling2D(size=(2, 2))(conv8)
    merge9 = Concatenate()([conv1, up9])
    conv9 = Conv2D(64, 3, padding='same')(merge9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, 3, padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)

    outputs = Conv2D(num_classes, 1, activation='softmax')(conv9)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Define the parameters
img_height = 224
img_width = 224
num_channels = 4  # Variable to select the number of input channels
num_classes = 6   # Here is the number of classes you need to predict +1
batch_size = 4   # Reduce the batch size to decrease memory usage

# Initialize the U-Net model
input_shape = (img_height, img_width, num_channels)
model = unet_advanced(input_shape, num_classes=num_classes)
model.summary()

# Define the callback to save the best epoch
saved_model_path = "../saved_model"
checkpoint_cb = ModelCheckpoint(
    filepath=saved_model_path,  # Path to save the best model
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_format="tf",  # Ensure SavedModel format
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_images,
    train_masks,
    batch_size=batch_size,
    epochs=100,
    validation_data=(val_images, val_masks),
    callbacks=[checkpoint_cb]
)

print(f"The best model has been saved in SavedModel format at {saved_model_path}.")
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 4  0           []
#                                 )]
#
#  conv2d_57 (Conv2D)             (None, 224, 224, 64  2368        ['input_4[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 224, 224, 64  256        ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  activation_54 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_54[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 224, 224, 64  36928       ['activation_54[0][0]']
#                                 )
#
#  batch_normalization_55 (BatchN  (None, 224, 224, 64  256        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  activation_55 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_55[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 112, 112, 64  0          ['activation_55[0][0]']
#  )                              )
#
#  dropout_12 (Dropout)           (None, 112, 112, 64  0           ['max_pooling2d_12[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 112, 112, 12  73856       ['dropout_12[0][0]']
#                                 8)
#
#  batch_normalization_56 (BatchN  (None, 112, 112, 12  512        ['conv2d_59[0][0]']
#  ormalization)                  8)
#
#  activation_56 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_56[0][0]']
#                                 8)
#
#  conv2d_60 (Conv2D)             (None, 112, 112, 12  147584      ['activation_56[0][0]']
#                                 8)
#
#  batch_normalization_57 (BatchN  (None, 112, 112, 12  512        ['conv2d_60[0][0]']
#  ormalization)                  8)
#
#  activation_57 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_57[0][0]']
#                                 8)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 56, 56, 128)  0          ['activation_57[0][0]']
#  )
#
#  dropout_13 (Dropout)           (None, 56, 56, 128)  0           ['max_pooling2d_13[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 56, 56, 256)  295168      ['dropout_13[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_59[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 28, 28, 256)  0          ['activation_59[0][0]']
#  )
#
#  dropout_14 (Dropout)           (None, 28, 28, 256)  0           ['max_pooling2d_14[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 28, 28, 512)  1180160     ['dropout_14[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_61[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 14, 14, 512)  0          ['activation_61[0][0]']
#  )
#
#  dropout_15 (Dropout)           (None, 14, 14, 512)  0           ['max_pooling2d_15[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 14, 14, 1024  4719616     ['dropout_15[0][0]']
#                                 )
#
#  batch_normalization_62 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_65[0][0]']
#  ormalization)                  )
#
#  activation_62 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_62[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 14, 14, 1024  9438208     ['activation_62[0][0]']
#                                 )
#
#  batch_normalization_63 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  activation_63 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_63[0][0]']
#                                 )
#
#  up_sampling2d_12 (UpSampling2D  (None, 28, 28, 1024  0          ['activation_63[0][0]']
#  )                              )
#
#  concatenate_12 (Concatenate)   (None, 28, 28, 1536  0           ['activation_61[0][0]',
#                                 )                                 'up_sampling2d_12[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 28, 28, 512)  7078400     ['concatenate_12[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_64[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_65[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 56, 56, 512)  0          ['activation_65[0][0]']
#  )
#
#  concatenate_13 (Concatenate)   (None, 56, 56, 768)  0           ['activation_59[0][0]',
#                                                                   'up_sampling2d_13[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 56, 56, 256)  1769728     ['concatenate_13[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_66[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_66[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_67[0][0]']
#
#  up_sampling2d_14 (UpSampling2D  (None, 112, 112, 25  0          ['activation_67[0][0]']
#  )                              6)
#
#  concatenate_14 (Concatenate)   (None, 112, 112, 38  0           ['activation_57[0][0]',
#                                 4)                                'up_sampling2d_14[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 112, 112, 12  442496      ['concatenate_14[0][0]']
#                                 8)
#
#  batch_normalization_68 (BatchN  (None, 112, 112, 12  512        ['conv2d_71[0][0]']
#  ormalization)                  8)
#
#  activation_68 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_68[0][0]']
#                                 8)
#
#  conv2d_72 (Conv2D)             (None, 112, 112, 12  147584      ['activation_68[0][0]']
#                                 8)
#
#  batch_normalization_69 (BatchN  (None, 112, 112, 12  512        ['conv2d_72[0][0]']
#  ormalization)                  8)
#
#  activation_69 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_69[0][0]']
#                                 8)
#
#  up_sampling2d_15 (UpSampling2D  (None, 224, 224, 12  0          ['activation_69[0][0]']
#  )                              8)
#
#  concatenate_15 (Concatenate)   (None, 224, 224, 19  0           ['activation_55[0][0]',
#                                 2)                                'up_sampling2d_15[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 224, 224, 64  110656      ['concatenate_15[0][0]']
#                                 )
#
#  batch_normalization_70 (BatchN  (None, 224, 224, 64  256        ['conv2d_73[0][0]']
#  ormalization)                  )
#
#  activation_70 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_70[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 224, 224, 64  36928       ['activation_70[0][0]']
#                                 )
#
#  batch_normalization_71 (BatchN  (None, 224, 224, 64  256        ['conv2d_74[0][0]']
#  ormalization)                  )
#
#  activation_71 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_71[0][0]']
#                                 )
#
#  conv2d_75 (Conv2D)             (None, 224, 224, 6)  390         ['activation_71[0][0]']
#
# ==================================================================================================
# Total params: 31,403,398
# Trainable params: 31,391,622
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 2.4734 - accuracy: 0.0679
# Epoch 1: val_loss improved from inf to 1.78832, saving model to ..\saved_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# 1/1 [==============================] - 27s 27s/step - loss: 2.4734 - accuracy: 0.0679 - val_loss: 1.7883 - val_accuracy: 0.4229
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8314 - accuracy: 0.3531
# Epoch 2: val_loss improved from 1.78832 to 1.78698, saving model to ..\saved_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# 1/1 [==============================] - 22s 22s/step - loss: 1.8314 - accuracy: 0.3531 - val_loss: 1.7870 - val_accuracy: 0.4374
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5284 - accuracy: 0.5275
# Epoch 3: val_loss improved from 1.78698 to 1.78324, saving model to ..\saved_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# 1/1 [==============================] - 21s 21s/step - loss: 1.5284 - accuracy: 0.5275 - val_loss: 1.7832 - val_accuracy: 0.4179
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3339 - accuracy: 0.5938
# Epoch 4: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 1.3339 - accuracy: 0.5938 - val_loss: 1.8547 - val_accuracy: 0.1676
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1947 - accuracy: 0.6610
# Epoch 5: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 1.1947 - accuracy: 0.6610 - val_loss: 2.5272 - val_accuracy: 0.1521
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0825 - accuracy: 0.7226
# Epoch 6: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 1.0825 - accuracy: 0.7226 - val_loss: 4.0710 - val_accuracy: 0.1515
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0050 - accuracy: 0.7405
# Epoch 7: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 1.0050 - accuracy: 0.7405 - val_loss: 6.4996 - val_accuracy: 0.1509
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9408 - accuracy: 0.7498
# Epoch 8: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.9408 - accuracy: 0.7498 - val_loss: 9.6096 - val_accuracy: 0.1507
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8948 - accuracy: 0.7548
# Epoch 9: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.8948 - accuracy: 0.7548 - val_loss: 12.7090 - val_accuracy: 0.1506
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8479 - accuracy: 0.7625
# Epoch 10: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.8479 - accuracy: 0.7625 - val_loss: 16.6231 - val_accuracy: 0.1505
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7995 - accuracy: 0.7745
# Epoch 11: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.7995 - accuracy: 0.7745 - val_loss: 17.0054 - val_accuracy: 0.1504
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7614 - accuracy: 0.7815
# Epoch 12: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.7614 - accuracy: 0.7815 - val_loss: 16.1326 - val_accuracy: 0.1496
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7310 - accuracy: 0.7850
# Epoch 13: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.7310 - accuracy: 0.7850 - val_loss: 18.5554 - val_accuracy: 0.1505
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7224 - accuracy: 0.7867
# Epoch 14: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.7224 - accuracy: 0.7867 - val_loss: 15.3822 - val_accuracy: 0.1561
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.7867
# Epoch 15: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.7023 - accuracy: 0.7867 - val_loss: 17.9500 - val_accuracy: 0.1618
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6763 - accuracy: 0.7909
# Epoch 16: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.6763 - accuracy: 0.7909 - val_loss: 19.4056 - val_accuracy: 0.1636
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6501 - accuracy: 0.7968
# Epoch 17: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.6501 - accuracy: 0.7968 - val_loss: 20.7412 - val_accuracy: 0.1755
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6316 - accuracy: 0.8045
# Epoch 18: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.6316 - accuracy: 0.8045 - val_loss: 23.3889 - val_accuracy: 0.1748
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6160 - accuracy: 0.8067
# Epoch 19: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.6160 - accuracy: 0.8067 - val_loss: 26.6204 - val_accuracy: 0.1766
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.8107
# Epoch 20: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5991 - accuracy: 0.8107 - val_loss: 27.5169 - val_accuracy: 0.1729
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5854 - accuracy: 0.8150
# Epoch 21: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.5854 - accuracy: 0.8150 - val_loss: 29.4324 - val_accuracy: 0.1698
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.8168
# Epoch 22: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5722 - accuracy: 0.8168 - val_loss: 31.3276 - val_accuracy: 0.1589
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5596 - accuracy: 0.8201
# Epoch 23: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5596 - accuracy: 0.8201 - val_loss: 31.5497 - val_accuracy: 0.1563
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5515 - accuracy: 0.8219
# Epoch 24: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5515 - accuracy: 0.8219 - val_loss: 29.9346 - val_accuracy: 0.1535
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5394 - accuracy: 0.8236
# Epoch 25: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5394 - accuracy: 0.8236 - val_loss: 30.3019 - val_accuracy: 0.1508
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5243 - accuracy: 0.8301
# Epoch 26: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5243 - accuracy: 0.8301 - val_loss: 31.6087 - val_accuracy: 0.1508
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5212 - accuracy: 0.8299
# Epoch 27: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.5212 - accuracy: 0.8299 - val_loss: 31.1634 - val_accuracy: 0.1515
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5088 - accuracy: 0.8319
# Epoch 28: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5088 - accuracy: 0.8319 - val_loss: 31.3780 - val_accuracy: 0.1580
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.8334
# Epoch 29: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.5018 - accuracy: 0.8334 - val_loss: 31.0560 - val_accuracy: 0.1651
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5011 - accuracy: 0.8331
# Epoch 30: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.5011 - accuracy: 0.8331 - val_loss: 30.5057 - val_accuracy: 0.1719
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.8357
# Epoch 31: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4888 - accuracy: 0.8357 - val_loss: 24.6531 - val_accuracy: 0.1826
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.8355
# Epoch 32: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4853 - accuracy: 0.8355 - val_loss: 21.9270 - val_accuracy: 0.1941
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.8388
# Epoch 33: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4790 - accuracy: 0.8388 - val_loss: 22.2303 - val_accuracy: 0.1940
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.8388
# Epoch 34: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4724 - accuracy: 0.8388 - val_loss: 24.9825 - val_accuracy: 0.1897
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.8416
# Epoch 35: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4670 - accuracy: 0.8416 - val_loss: 22.3277 - val_accuracy: 0.1918
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.8442
# Epoch 36: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4574 - accuracy: 0.8442 - val_loss: 25.2704 - val_accuracy: 0.1772
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.8446
# Epoch 37: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4533 - accuracy: 0.8446 - val_loss: 30.5730 - val_accuracy: 0.1721
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.8461
# Epoch 38: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4484 - accuracy: 0.8461 - val_loss: 29.4285 - val_accuracy: 0.1717
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4431 - accuracy: 0.8475
# Epoch 39: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4431 - accuracy: 0.8475 - val_loss: 26.3200 - val_accuracy: 0.1612
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8491
# Epoch 40: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4408 - accuracy: 0.8491 - val_loss: 32.1600 - val_accuracy: 0.1562
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4327 - accuracy: 0.8513
# Epoch 41: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4327 - accuracy: 0.8513 - val_loss: 36.8556 - val_accuracy: 0.1401
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4291 - accuracy: 0.8510
# Epoch 42: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.4291 - accuracy: 0.8510 - val_loss: 33.6488 - val_accuracy: 0.0393
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4247 - accuracy: 0.8530
# Epoch 43: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.4247 - accuracy: 0.8530 - val_loss: 31.0788 - val_accuracy: 0.0320
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8559
# Epoch 44: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.4212 - accuracy: 0.8559 - val_loss: 32.0844 - val_accuracy: 0.0301
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4162 - accuracy: 0.8558
# Epoch 45: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4162 - accuracy: 0.8558 - val_loss: 29.3326 - val_accuracy: 0.0307
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4104 - accuracy: 0.8563
# Epoch 46: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4104 - accuracy: 0.8563 - val_loss: 26.2389 - val_accuracy: 0.0309
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4040 - accuracy: 0.8591
# Epoch 47: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.4040 - accuracy: 0.8591 - val_loss: 22.6134 - val_accuracy: 0.0268
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3973 - accuracy: 0.8626
# Epoch 48: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3973 - accuracy: 0.8626 - val_loss: 19.1763 - val_accuracy: 0.0286
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8615
# Epoch 49: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3971 - accuracy: 0.8615 - val_loss: 20.0701 - val_accuracy: 0.0310
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3921 - accuracy: 0.8622
# Epoch 50: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3921 - accuracy: 0.8622 - val_loss: 21.5008 - val_accuracy: 0.0310
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8622
# Epoch 51: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3907 - accuracy: 0.8622 - val_loss: 17.7493 - val_accuracy: 0.0293
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8638
# Epoch 52: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3890 - accuracy: 0.8638 - val_loss: 15.2510 - val_accuracy: 0.0297
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3835 - accuracy: 0.8668
# Epoch 53: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3835 - accuracy: 0.8668 - val_loss: 13.5450 - val_accuracy: 0.0294
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3781 - accuracy: 0.8674
# Epoch 54: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3781 - accuracy: 0.8674 - val_loss: 12.6613 - val_accuracy: 0.0254
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8680
# Epoch 55: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3753 - accuracy: 0.8680 - val_loss: 12.3548 - val_accuracy: 0.0286
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8678
# Epoch 56: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3726 - accuracy: 0.8678 - val_loss: 10.0285 - val_accuracy: 0.0302
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3708 - accuracy: 0.8696
# Epoch 57: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3708 - accuracy: 0.8696 - val_loss: 9.7384 - val_accuracy: 0.0315
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3629 - accuracy: 0.8722
# Epoch 58: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3629 - accuracy: 0.8722 - val_loss: 9.6117 - val_accuracy: 0.0348
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3599 - accuracy: 0.8731
# Epoch 59: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3599 - accuracy: 0.8731 - val_loss: 9.0867 - val_accuracy: 0.0335
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3577 - accuracy: 0.8719
# Epoch 60: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3577 - accuracy: 0.8719 - val_loss: 8.3833 - val_accuracy: 0.0366
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3571 - accuracy: 0.8726
# Epoch 61: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3571 - accuracy: 0.8726 - val_loss: 9.1865 - val_accuracy: 0.0373
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3511 - accuracy: 0.8750
# Epoch 62: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3511 - accuracy: 0.8750 - val_loss: 9.6285 - val_accuracy: 0.0374
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8773
# Epoch 63: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3468 - accuracy: 0.8773 - val_loss: 9.4637 - val_accuracy: 0.0364
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8755
# Epoch 64: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3488 - accuracy: 0.8755 - val_loss: 8.2315 - val_accuracy: 0.0402
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3494 - accuracy: 0.8739
# Epoch 65: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3494 - accuracy: 0.8739 - val_loss: 7.3059 - val_accuracy: 0.0437
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3557 - accuracy: 0.8724
# Epoch 66: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3557 - accuracy: 0.8724 - val_loss: 6.8435 - val_accuracy: 0.0410
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3455 - accuracy: 0.8753
# Epoch 67: val_loss did not improve from 1.78324
# 1/1 [==============================] - 2s 2s/step - loss: 0.3455 - accuracy: 0.8753 - val_loss: 6.4277 - val_accuracy: 0.0470
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.8801
# Epoch 68: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3357 - accuracy: 0.8801 - val_loss: 6.1321 - val_accuracy: 0.0480
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.8807
# Epoch 69: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3347 - accuracy: 0.8807 - val_loss: 5.9020 - val_accuracy: 0.0557
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3308 - accuracy: 0.8807
# Epoch 70: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3308 - accuracy: 0.8807 - val_loss: 5.2994 - val_accuracy: 0.0793
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.8815
# Epoch 71: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3293 - accuracy: 0.8815 - val_loss: 5.6941 - val_accuracy: 0.0589
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3310 - accuracy: 0.8808
# Epoch 72: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3310 - accuracy: 0.8808 - val_loss: 5.4665 - val_accuracy: 0.0794
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3210 - accuracy: 0.8836
# Epoch 73: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3210 - accuracy: 0.8836 - val_loss: 5.1169 - val_accuracy: 0.1094
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3261 - accuracy: 0.8822
# Epoch 74: val_loss did not improve from 1.78324
# 1/1 [==============================] - 5s 5s/step - loss: 0.3261 - accuracy: 0.8822 - val_loss: 5.0353 - val_accuracy: 0.1104
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3229 - accuracy: 0.8839
# Epoch 75: val_loss did not improve from 1.78324
# 1/1 [==============================] - 4s 4s/step - loss: 0.3229 - accuracy: 0.8839 - val_loss: 4.9489 - val_accuracy: 0.1115
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8869
# Epoch 76: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3139 - accuracy: 0.8869 - val_loss: 4.6809 - val_accuracy: 0.1172
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.8852
# Epoch 77: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3152 - accuracy: 0.8852 - val_loss: 4.4056 - val_accuracy: 0.1148
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.8860
# Epoch 78: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3146 - accuracy: 0.8860 - val_loss: 4.1241 - val_accuracy: 0.1240
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.8883
# Epoch 79: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3077 - accuracy: 0.8883 - val_loss: 4.3913 - val_accuracy: 0.1220
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3057 - accuracy: 0.8886
# Epoch 80: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3057 - accuracy: 0.8886 - val_loss: 4.3997 - val_accuracy: 0.1266
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8910
# Epoch 81: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.3005 - accuracy: 0.8910 - val_loss: 4.3805 - val_accuracy: 0.1230
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8913
# Epoch 82: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2987 - accuracy: 0.8913 - val_loss: 4.3116 - val_accuracy: 0.1271
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.8934
# Epoch 83: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2952 - accuracy: 0.8934 - val_loss: 4.3061 - val_accuracy: 0.1291
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8934
# Epoch 84: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2946 - accuracy: 0.8934 - val_loss: 4.0212 - val_accuracy: 0.1419
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.8940
# Epoch 85: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2907 - accuracy: 0.8940 - val_loss: 4.1168 - val_accuracy: 0.1373
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.8939
# Epoch 86: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2890 - accuracy: 0.8939 - val_loss: 4.1280 - val_accuracy: 0.1477
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.8951
# Epoch 87: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2863 - accuracy: 0.8951 - val_loss: 4.0429 - val_accuracy: 0.1751
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.8946
# Epoch 88: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2886 - accuracy: 0.8946 - val_loss: 4.2246 - val_accuracy: 0.1625
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.8966
# Epoch 89: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2831 - accuracy: 0.8966 - val_loss: 4.1952 - val_accuracy: 0.1746
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.8963
# Epoch 90: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2814 - accuracy: 0.8963 - val_loss: 3.9650 - val_accuracy: 0.1783
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8956
# Epoch 91: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2810 - accuracy: 0.8956 - val_loss: 3.8357 - val_accuracy: 0.1834
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.8962
# Epoch 92: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2822 - accuracy: 0.8962 - val_loss: 3.9709 - val_accuracy: 0.1714
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2837 - accuracy: 0.8938
# Epoch 93: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2837 - accuracy: 0.8938 - val_loss: 4.2382 - val_accuracy: 0.1684
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2802 - accuracy: 0.8964
# Epoch 94: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2802 - accuracy: 0.8964 - val_loss: 4.1775 - val_accuracy: 0.1668
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.9001
# Epoch 95: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2715 - accuracy: 0.9001 - val_loss: 4.1539 - val_accuracy: 0.1618
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.8987
# Epoch 96: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2738 - accuracy: 0.8987 - val_loss: 4.2196 - val_accuracy: 0.1488
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2690 - accuracy: 0.9006
# Epoch 97: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2690 - accuracy: 0.9006 - val_loss: 4.1551 - val_accuracy: 0.1530
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9012
# Epoch 98: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2661 - accuracy: 0.9012 - val_loss: 4.2267 - val_accuracy: 0.1497
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2610 - accuracy: 0.9026
# Epoch 99: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2610 - accuracy: 0.9026 - val_loss: 4.3758 - val_accuracy: 0.1487
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.9040
# Epoch 100: val_loss did not improve from 1.78324
# 1/1 [==============================] - 3s 3s/step - loss: 0.2620 - accuracy: 0.9040 - val_loss: 4.3813 - val_accuracy: 0.1556
# The best model has been saved in SavedModel format at ../saved_model.

# %%
# Cell modified from original file due with problems with kernel crashing when plotting accuracy metrics

# Create a DataFrame with the metric values
metrics = pd.DataFrame({
    'Epoch': list(range(1, len(history.history['accuracy']) + 1)),
    'Train Accuracy': history.history['accuracy'],
    'Validation Accuracy': history.history['val_accuracy'],
    'Train Loss': history.history['loss'],
    'Validation Loss': history.history['val_loss']
})

# Save to Excel
metrics.to_excel('../results/metric_values.xlsx', index=False)

# %% [markdown]
# Step 4 : Displaying results

# %%
# Normalize the image
def normalize_img(img):
    return img / np.max(img)

# Load a test image and keep the geo-referencing information
def load_test_image(image_path):
    img = tiff.imread(image_path).astype(np.float32)
    img = normalize_img(img)
    img = np.expand_dims(img, axis=0)
    
    # Read the geo-referencing info (e.g., transform and CRS)
    with rasterio.open(image_path) as src:
        transform = src.transform
        crs = src.crs
        
    return img, transform, crs

# Load a test label
def load_test_mask(mask_path):
    mask = tiff.imread(mask_path).astype(np.uint8)
    return mask

# Paths to the test image and test label
test_image_path = '../data/patch/test/images/patch_3.0.tif'  
test_mask_path = '../data/patch/test/labels/patch_3.0.tif'

# Load the saved model (SavedModel format)
saved_model_path = '../saved_model'  # Path to the directory of the SavedModel
model = tf.keras.models.load_model(saved_model_path)

# Load and prepare the test image and test label
test_image, transform, crs = load_test_image(test_image_path)
test_mask = load_test_mask(test_mask_path)
print(f'Shape of test image: {test_image.shape}')
print(f'Shape of test mask: {test_mask.shape}')

# Predict the segmentation of the test image
prediction = model.predict(test_image)
predicted_mask = tf.argmax(prediction, axis=-1)
predicted_mask = tf.squeeze(predicted_mask).numpy()

# Save the predicted mask with geo-referencing
predicted_mask_path = '../results/prediction/predicted_mask.tif'  # Replace with the path where you want to save the predicted mask

# Write the predicted mask using rasterio, preserving the geo-referencing
with rasterio.open(test_image_path) as src:
    meta = src.meta  # Get the metadata (including the transform)
    meta.update(driver='GTiff', dtype=rasterio.uint8, count=1)  # Update the metadata to match the predicted mask's data type and single band count
    
    # Save the predicted mask as a georeferenced TIFF
    with rasterio.open(predicted_mask_path, 'w', **meta) as dst:
        dst.write(predicted_mask, 1)  # Write the predicted mask as the first band

print(f'Predicted mask saved as {predicted_mask_path}')
# Out:
# Shape of test image: (1, 224, 224, 4)
# Shape of test mask: (224, 224)
# 1/1 [==============================] - 1s 728ms/step
# Predicted mask saved as ../results/prediction/predicted_mask.tif
