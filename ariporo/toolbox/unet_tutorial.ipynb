# %% [markdown]
# Step 1 : Patch Extraction

# %%
import os
import numpy as np
import tifffile as tiff
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, BatchNormalization, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import rasterio
from rasterio.mask import mask
from rasterio.transform import from_origin
import geopandas as gpd
import cv2
import random
import pandas as pd

# %%
def extract_patches(image_path, label_path, shapefile_path, output_dir, train_ratio=0.75, val_ratio=0.2, test_ratio=0.05):
    
    with rasterio.open(image_path) as src_img:
        
        with rasterio.open(label_path) as src_lbl:
            
            grid = gpd.read_file(shapefile_path) #Load the satellite image, load the labels, and then the grid containing the patches. 
            
            train_img_dir = os.path.join(output_dir, 'train/images')
            val_img_dir = os.path.join(output_dir, 'validation/images')
            test_img_dir = os.path.join(output_dir, 'test/images')

            train_lbl_dir = os.path.join(output_dir, 'train/labels')
            val_lbl_dir = os.path.join(output_dir, 'validation/labels')
            test_lbl_dir = os.path.join(output_dir, 'test/labels')
            #Create the train, validation, and test directories if they do not already exist.
            
            for dir_path in [train_img_dir, val_img_dir, test_img_dir, train_lbl_dir, val_lbl_dir, test_lbl_dir]:
                if not os.path.exists(dir_path):
                    os.makedirs(dir_path)

            
            indices = list(grid.index)
            random.shuffle(indices)
            # Shuffle the patch indices for a random distribution
            
            num_patches = len(indices)
            
            #num_train = int(train_ratio * num_patches)
            #num_val = int(val_ratio * num_patches)
            #num_test = num_patches - num_train - num_val

            # Ensure we have at least 1 patch for each split
            num_train = max(1, int(train_ratio * num_patches))
            num_val = max(1, int(val_ratio * num_patches))
            num_test = max(1, num_patches - num_train - num_val)

            # Calculate the sizes of the train, validation, and test sets.
            
            train_indices = indices[:num_train]
            val_indices = indices[num_train:num_train + num_val]
            test_indices = indices[num_train + num_val:]

            
            def save_patch_and_label(patch, label, transform, output_img_subdir, output_lbl_subdir, patch_filename):
                
                patch_img_path = os.path.join(output_img_subdir, patch_filename)
                with rasterio.open(
                    patch_img_path, 'w',
                    driver='GTiff',
                    height=224, width=224,
                    count=4, dtype=patch.dtype, #Set the count variable according to the number of spectral bands you have.
                    crs=src_img.crs, transform=transform
                ) as dst_img:
                    dst_img.write(patch)
                print(f"Image patch {patch_filename} saved in {output_img_subdir}.")

                
                patch_lbl_path = os.path.join(output_lbl_subdir, patch_filename)
                with rasterio.open(
                    patch_lbl_path, 'w',
                    driver='GTiff',
                    height=224, width=224,
                    count=1, dtype=label.dtype,  # Single channel for labels
                    crs=src_lbl.crs, transform=transform
                ) as dst_lbl:
                    dst_lbl.write(label[0, :, :], 1)  # Correcting the write operation
                print(f"Label patch {patch_filename} saved in {output_lbl_subdir}.")

            
            for idx, row in grid.iterrows():
                geom = [row['geometry']]
                auto_value = row['AUTO']  # Column with unique identifiers

                # Extract the patch for the image
                patch_img, transform = mask(src_img, geom, crop=True)
                patch_lbl, _ = mask(src_lbl, geom, crop=True)

                # Check the patch size and resize if necessary (for the image and the label)
                height_img, width_img = patch_img.shape[1], patch_img.shape[2]
                height_lbl, width_lbl = patch_lbl.shape[1], patch_lbl.shape[2]
                
                if height_img != 224 or width_img != 224:
                    resized_patch_img = np.zeros((4, 224, 224), dtype=patch_img.dtype)
                    for i in range(4):
                        resized_patch_img[i] = cv2.resize(patch_img[i], (224, 224), interpolation=cv2.INTER_LINEAR)
                    patch_img = resized_patch_img
                
                if height_lbl != 224 or width_lbl != 224:
                    resized_patch_lbl = cv2.resize(patch_lbl[0], (224, 224), interpolation=cv2.INTER_NEAREST)
                    patch_lbl = resized_patch_lbl[np.newaxis, :, :]  # Add channel dimension
                
                # Determine the directory to save the patch
                patch_filename = f"patch_{auto_value}.tif"
                if idx in train_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, train_img_dir, train_lbl_dir, patch_filename)
                elif idx in val_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, val_img_dir, val_lbl_dir, patch_filename)
                elif idx in test_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, test_img_dir, test_lbl_dir, patch_filename)

    print("Patch and label extraction completed, and distribution performed.")

# %%
image_path = "../data/input/image_s2.tif"
label_path = "../data/input/label.tif"
shapefile_path = "../data/input/grid.shp"
output_dir = "../data/patch"
extract_patches(image_path, label_path, shapefile_path, output_dir)
# Out:
# Image patch patch_38.0.tif saved in ../data/patch\train/images.
# Label patch patch_38.0.tif saved in ../data/patch\train/labels.
# Image patch patch_39.0.tif saved in ../data/patch\train/images.
# Label patch patch_39.0.tif saved in ../data/patch\train/labels.
# Image patch patch_40.0.tif saved in ../data/patch\validation/images.
# Label patch patch_40.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_41.0.tif saved in ../data/patch\test/images.
# Label patch patch_41.0.tif saved in ../data/patch\test/labels.
# Image patch patch_42.0.tif saved in ../data/patch\train/images.
# Label patch patch_42.0.tif saved in ../data/patch\train/labels.
# Image patch patch_43.0.tif saved in ../data/patch\train/images.
# Label patch patch_43.0.tif saved in ../data/patch\train/labels.
# Image patch patch_44.0.tif saved in ../data/patch\train/images.
# Label patch patch_44.0.tif saved in ../data/patch\train/labels.
# Image patch patch_45.0.tif saved in ../data/patch\train/images.
# Label patch patch_45.0.tif saved in ../data/patch\train/labels.
# Image patch patch_46.0.tif saved in ../data/patch\validation/images.
# Label patch patch_46.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_47.0.tif saved in ../data/patch\validation/images.
# Label patch patch_47.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_48.0.tif saved in ../data/patch\train/images.
# Label patch patch_48.0.tif saved in ../data/patch\train/labels.
# Image patch patch_49.0.tif saved in ../data/patch\train/images.
# Label patch patch_49.0.tif saved in ../data/patch\train/labels.
# Image patch patch_50.0.tif saved in ../data/patch\train/images.
# Label patch patch_50.0.tif saved in ../data/patch\train/labels.
# Image patch patch_51.0.tif saved in ../data/patch\train/images.
# Label patch patch_51.0.tif saved in ../data/patch\train/labels.
# Image patch patch_52.0.tif saved in ../data/patch\test/images.
# Label patch patch_52.0.tif saved in ../data/patch\test/labels.
# Image patch patch_53.0.tif saved in ../data/patch\validation/images.
# Label patch patch_53.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_54.0.tif saved in ../data/patch\train/images.
# Label patch patch_54.0.tif saved in ../data/patch\train/labels.
# Image patch patch_55.0.tif saved in ../data/patch\test/images.
# Label patch patch_55.0.tif saved in ../data/patch\test/labels.
# Image patch patch_56.0.tif saved in ../data/patch\train/images.
# Label patch patch_56.0.tif saved in ../data/patch\train/labels.
# Image patch patch_57.0.tif saved in ../data/patch\train/images.
# Label patch patch_57.0.tif saved in ../data/patch\train/labels.
# Image patch patch_58.0.tif saved in ../data/patch\train/images.
# Label patch patch_58.0.tif saved in ../data/patch\train/labels.
# Image patch patch_59.0.tif saved in ../data/patch\validation/images.
# Label patch patch_59.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_60.0.tif saved in ../data/patch\test/images.
# Label patch patch_60.0.tif saved in ../data/patch\test/labels.
# Image patch patch_61.0.tif saved in ../data/patch\train/images.
# Label patch patch_61.0.tif saved in ../data/patch\train/labels.
# Image patch patch_62.0.tif saved in ../data/patch\train/images.
# Label patch patch_62.0.tif saved in ../data/patch\train/labels.
# Image patch patch_63.0.tif saved in ../data/patch\train/images.
# Label patch patch_63.0.tif saved in ../data/patch\train/labels.
# Image patch patch_64.0.tif saved in ../data/patch\train/images.
# Label patch patch_64.0.tif saved in ../data/patch\train/labels.
# Image patch patch_65.0.tif saved in ../data/patch\train/images.
# Label patch patch_65.0.tif saved in ../data/patch\train/labels.
# Image patch patch_66.0.tif saved in ../data/patch\train/images.
# Label patch patch_66.0.tif saved in ../data/patch\train/labels.
# Image patch patch_67.0.tif saved in ../data/patch\train/images.
# Label patch patch_67.0.tif saved in ../data/patch\train/labels.
# Image patch patch_68.0.tif saved in ../data/patch\train/images.
# Label patch patch_68.0.tif saved in ../data/patch\train/labels.
# Image patch patch_69.0.tif saved in ../data/patch\train/images.
# Label patch patch_69.0.tif saved in ../data/patch\train/labels.
# Image patch patch_70.0.tif saved in ../data/patch\train/images.
# Label patch patch_70.0.tif saved in ../data/patch\train/labels.
# Image patch patch_71.0.tif saved in ../data/patch\train/images.
# Label patch patch_71.0.tif saved in ../data/patch\train/labels.
# Image patch patch_72.0.tif saved in ../data/patch\test/images.
# Label patch patch_72.0.tif saved in ../data/patch\test/labels.
# Image patch patch_75.0.tif saved in ../data/patch\train/images.
# Label patch patch_75.0.tif saved in ../data/patch\train/labels.
# Image patch patch_76.0.tif saved in ../data/patch\train/images.
# Label patch patch_76.0.tif saved in ../data/patch\train/labels.
# Image patch patch_77.0.tif saved in ../data/patch\validation/images.
# Label patch patch_77.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_78.0.tif saved in ../data/patch\train/images.
# Label patch patch_78.0.tif saved in ../data/patch\train/labels.
# Image patch patch_79.0.tif saved in ../data/patch\validation/images.
# Label patch patch_79.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_80.0.tif saved in ../data/patch\train/images.
# Label patch patch_80.0.tif saved in ../data/patch\train/labels.
# Image patch patch_81.0.tif saved in ../data/patch\train/images.
# Label patch patch_81.0.tif saved in ../data/patch\train/labels.
# Image patch patch_82.0.tif saved in ../data/patch\validation/images.
# Label patch patch_82.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_83.0.tif saved in ../data/patch\validation/images.
# Label patch patch_83.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_84.0.tif saved in ../data/patch\train/images.
# Label patch patch_84.0.tif saved in ../data/patch\train/labels.
# Image patch patch_85.0.tif saved in ../data/patch\train/images.
# Label patch patch_85.0.tif saved in ../data/patch\train/labels.
# Image patch patch_86.0.tif saved in ../data/patch\train/images.
# Label patch patch_86.0.tif saved in ../data/patch\train/labels.
# Image patch patch_87.0.tif saved in ../data/patch\train/images.
# Label patch patch_87.0.tif saved in ../data/patch\train/labels.
# Image patch patch_88.0.tif saved in ../data/patch\train/images.
# Label patch patch_88.0.tif saved in ../data/patch\train/labels.
# Image patch patch_89.0.tif saved in ../data/patch\train/images.
# Label patch patch_89.0.tif saved in ../data/patch\train/labels.
# Image patch patch_90.0.tif saved in ../data/patch\train/images.
# Label patch patch_90.0.tif saved in ../data/patch\train/labels.
# Image patch patch_91.0.tif saved in ../data/patch\train/images.
# Label patch patch_91.0.tif saved in ../data/patch\train/labels.
# Image patch patch_92.0.tif saved in ../data/patch\train/images.
# Label patch patch_92.0.tif saved in ../data/patch\train/labels.
# Image patch patch_93.0.tif saved in ../data/patch\train/images.
# Label patch patch_93.0.tif saved in ../data/patch\train/labels.
# Image patch patch_94.0.tif saved in ../data/patch\validation/images.
# Label patch patch_94.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_95.0.tif saved in ../data/patch\train/images.
# Label patch patch_95.0.tif saved in ../data/patch\train/labels.
# Image patch patch_96.0.tif saved in ../data/patch\train/images.
# Label patch patch_96.0.tif saved in ../data/patch\train/labels.
# Image patch patch_97.0.tif saved in ../data/patch\train/images.
# Label patch patch_97.0.tif saved in ../data/patch\train/labels.
# Image patch patch_98.0.tif saved in ../data/patch\train/images.
# Label patch patch_98.0.tif saved in ../data/patch\train/labels.
# Image patch patch_99.0.tif saved in ../data/patch\validation/images.
# Label patch patch_99.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_100.0.tif saved in ../data/patch\train/images.
# Label patch patch_100.0.tif saved in ../data/patch\train/labels.
# Image patch patch_101.0.tif saved in ../data/patch\train/images.
# Label patch patch_101.0.tif saved in ../data/patch\train/labels.
# Image patch patch_102.0.tif saved in ../data/patch\train/images.
# Label patch patch_102.0.tif saved in ../data/patch\train/labels.
# Image patch patch_103.0.tif saved in ../data/patch\train/images.
# Label patch patch_103.0.tif saved in ../data/patch\train/labels.
# Image patch patch_104.0.tif saved in ../data/patch\train/images.
# Label patch patch_104.0.tif saved in ../data/patch\train/labels.
# Image patch patch_105.0.tif saved in ../data/patch\train/images.
# Label patch patch_105.0.tif saved in ../data/patch\train/labels.
# Image patch patch_106.0.tif saved in ../data/patch\validation/images.
# Label patch patch_106.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_107.0.tif saved in ../data/patch\train/images.
# Label patch patch_107.0.tif saved in ../data/patch\train/labels.
# Image patch patch_108.0.tif saved in ../data/patch\validation/images.
# Label patch patch_108.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_109.0.tif saved in ../data/patch\train/images.
# Label patch patch_109.0.tif saved in ../data/patch\train/labels.
# Image patch patch_112.0.tif saved in ../data/patch\train/images.
# Label patch patch_112.0.tif saved in ../data/patch\train/labels.
# Image patch patch_113.0.tif saved in ../data/patch\test/images.
# Label patch patch_113.0.tif saved in ../data/patch\test/labels.
# Image patch patch_114.0.tif saved in ../data/patch\validation/images.
# Label patch patch_114.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_115.0.tif saved in ../data/patch\train/images.
# Label patch patch_115.0.tif saved in ../data/patch\train/labels.
# Image patch patch_116.0.tif saved in ../data/patch\train/images.
# Label patch patch_116.0.tif saved in ../data/patch\train/labels.
# Image patch patch_117.0.tif saved in ../data/patch\validation/images.
# Label patch patch_117.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_118.0.tif saved in ../data/patch\train/images.
# Label patch patch_118.0.tif saved in ../data/patch\train/labels.
# Image patch patch_119.0.tif saved in ../data/patch\train/images.
# Label patch patch_119.0.tif saved in ../data/patch\train/labels.
# Image patch patch_120.0.tif saved in ../data/patch\train/images.
# Label patch patch_120.0.tif saved in ../data/patch\train/labels.
# Image patch patch_121.0.tif saved in ../data/patch\train/images.
# Label patch patch_121.0.tif saved in ../data/patch\train/labels.
# Image patch patch_122.0.tif saved in ../data/patch\validation/images.
# Label patch patch_122.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_123.0.tif saved in ../data/patch\train/images.
# Label patch patch_123.0.tif saved in ../data/patch\train/labels.
# Image patch patch_124.0.tif saved in ../data/patch\train/images.
# Label patch patch_124.0.tif saved in ../data/patch\train/labels.
# Image patch patch_125.0.tif saved in ../data/patch\train/images.
# Label patch patch_125.0.tif saved in ../data/patch\train/labels.
# Image patch patch_126.0.tif saved in ../data/patch\train/images.
# Label patch patch_126.0.tif saved in ../data/patch\train/labels.
# Image patch patch_127.0.tif saved in ../data/patch\validation/images.
# Label patch patch_127.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_128.0.tif saved in ../data/patch\validation/images.
# Label patch patch_128.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_129.0.tif saved in ../data/patch\train/images.
# Label patch patch_129.0.tif saved in ../data/patch\train/labels.
# Image patch patch_130.0.tif saved in ../data/patch\train/images.
# Label patch patch_130.0.tif saved in ../data/patch\train/labels.
# Image patch patch_131.0.tif saved in ../data/patch\train/images.
# Label patch patch_131.0.tif saved in ../data/patch\train/labels.
# Image patch patch_132.0.tif saved in ../data/patch\train/images.
# Label patch patch_132.0.tif saved in ../data/patch\train/labels.
# Image patch patch_133.0.tif saved in ../data/patch\train/images.
# Label patch patch_133.0.tif saved in ../data/patch\train/labels.
# Image patch patch_134.0.tif saved in ../data/patch\train/images.
# Label patch patch_134.0.tif saved in ../data/patch\train/labels.
# Image patch patch_135.0.tif saved in ../data/patch\train/images.
# Label patch patch_135.0.tif saved in ../data/patch\train/labels.
# Image patch patch_136.0.tif saved in ../data/patch\validation/images.
# Label patch patch_136.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_137.0.tif saved in ../data/patch\test/images.
# Label patch patch_137.0.tif saved in ../data/patch\test/labels.
# Image patch patch_138.0.tif saved in ../data/patch\train/images.
# Label patch patch_138.0.tif saved in ../data/patch\train/labels.
# Image patch patch_139.0.tif saved in ../data/patch\test/images.
# Label patch patch_139.0.tif saved in ../data/patch\test/labels.
# Image patch patch_140.0.tif saved in ../data/patch\train/images.
# Label patch patch_140.0.tif saved in ../data/patch\train/labels.
# Image patch patch_141.0.tif saved in ../data/patch\train/images.
# Label patch patch_141.0.tif saved in ../data/patch\train/labels.
# Image patch patch_142.0.tif saved in ../data/patch\train/images.
# Label patch patch_142.0.tif saved in ../data/patch\train/labels.
# Image patch patch_143.0.tif saved in ../data/patch\test/images.
# Label patch patch_143.0.tif saved in ../data/patch\test/labels.
# Image patch patch_144.0.tif saved in ../data/patch\train/images.
# Label patch patch_144.0.tif saved in ../data/patch\train/labels.
# Image patch patch_145.0.tif saved in ../data/patch\train/images.
# Label patch patch_145.0.tif saved in ../data/patch\train/labels.
# Image patch patch_146.0.tif saved in ../data/patch\validation/images.
# Label patch patch_146.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_149.0.tif saved in ../data/patch\test/images.
# Label patch patch_149.0.tif saved in ../data/patch\test/labels.
# Image patch patch_150.0.tif saved in ../data/patch\train/images.
# Label patch patch_150.0.tif saved in ../data/patch\train/labels.
# Image patch patch_151.0.tif saved in ../data/patch\validation/images.
# Label patch patch_151.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_152.0.tif saved in ../data/patch\train/images.
# Label patch patch_152.0.tif saved in ../data/patch\train/labels.
# Image patch patch_153.0.tif saved in ../data/patch\validation/images.
# Label patch patch_153.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_154.0.tif saved in ../data/patch\train/images.
# Label patch patch_154.0.tif saved in ../data/patch\train/labels.
# Image patch patch_155.0.tif saved in ../data/patch\train/images.
# Label patch patch_155.0.tif saved in ../data/patch\train/labels.
# Image patch patch_156.0.tif saved in ../data/patch\train/images.
# Label patch patch_156.0.tif saved in ../data/patch\train/labels.
# Image patch patch_157.0.tif saved in ../data/patch\train/images.
# Label patch patch_157.0.tif saved in ../data/patch\train/labels.
# Image patch patch_158.0.tif saved in ../data/patch\train/images.
# Label patch patch_158.0.tif saved in ../data/patch\train/labels.
# Image patch patch_159.0.tif saved in ../data/patch\train/images.
# Label patch patch_159.0.tif saved in ../data/patch\train/labels.
# Image patch patch_160.0.tif saved in ../data/patch\validation/images.
# Label patch patch_160.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_161.0.tif saved in ../data/patch\train/images.
# Label patch patch_161.0.tif saved in ../data/patch\train/labels.
# Image patch patch_162.0.tif saved in ../data/patch\train/images.
# Label patch patch_162.0.tif saved in ../data/patch\train/labels.
# Image patch patch_163.0.tif saved in ../data/patch\validation/images.
# Label patch patch_163.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_164.0.tif saved in ../data/patch\train/images.
# Label patch patch_164.0.tif saved in ../data/patch\train/labels.
# Image patch patch_165.0.tif saved in ../data/patch\validation/images.
# Label patch patch_165.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_166.0.tif saved in ../data/patch\train/images.
# Label patch patch_166.0.tif saved in ../data/patch\train/labels.
# Image patch patch_167.0.tif saved in ../data/patch\train/images.
# Label patch patch_167.0.tif saved in ../data/patch\train/labels.
# Image patch patch_168.0.tif saved in ../data/patch\train/images.
# Label patch patch_168.0.tif saved in ../data/patch\train/labels.
# Image patch patch_169.0.tif saved in ../data/patch\validation/images.
# Label patch patch_169.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_170.0.tif saved in ../data/patch\train/images.
# Label patch patch_170.0.tif saved in ../data/patch\train/labels.
# Image patch patch_171.0.tif saved in ../data/patch\test/images.
# Label patch patch_171.0.tif saved in ../data/patch\test/labels.
# Image patch patch_172.0.tif saved in ../data/patch\train/images.
# Label patch patch_172.0.tif saved in ../data/patch\train/labels.
# Image patch patch_173.0.tif saved in ../data/patch\train/images.
# Label patch patch_173.0.tif saved in ../data/patch\train/labels.
# Image patch patch_174.0.tif saved in ../data/patch\train/images.
# Label patch patch_174.0.tif saved in ../data/patch\train/labels.
# Image patch patch_175.0.tif saved in ../data/patch\validation/images.
# Label patch patch_175.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_176.0.tif saved in ../data/patch\validation/images.
# Label patch patch_176.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_177.0.tif saved in ../data/patch\validation/images.
# Label patch patch_177.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_178.0.tif saved in ../data/patch\train/images.
# Label patch patch_178.0.tif saved in ../data/patch\train/labels.
# Image patch patch_179.0.tif saved in ../data/patch\train/images.
# Label patch patch_179.0.tif saved in ../data/patch\train/labels.
# Image patch patch_180.0.tif saved in ../data/patch\validation/images.
# Label patch patch_180.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_181.0.tif saved in ../data/patch\test/images.
# Label patch patch_181.0.tif saved in ../data/patch\test/labels.
# Image patch patch_182.0.tif saved in ../data/patch\train/images.
# Label patch patch_182.0.tif saved in ../data/patch\train/labels.
# Image patch patch_183.0.tif saved in ../data/patch\train/images.
# Label patch patch_183.0.tif saved in ../data/patch\train/labels.
# Image patch patch_186.0.tif saved in ../data/patch\train/images.
# Label patch patch_186.0.tif saved in ../data/patch\train/labels.
# Image patch patch_187.0.tif saved in ../data/patch\validation/images.
# Label patch patch_187.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_188.0.tif saved in ../data/patch\train/images.
# Label patch patch_188.0.tif saved in ../data/patch\train/labels.
# Image patch patch_189.0.tif saved in ../data/patch\train/images.
# Label patch patch_189.0.tif saved in ../data/patch\train/labels.
# Image patch patch_190.0.tif saved in ../data/patch\train/images.
# Label patch patch_190.0.tif saved in ../data/patch\train/labels.
# Image patch patch_191.0.tif saved in ../data/patch\train/images.
# Label patch patch_191.0.tif saved in ../data/patch\train/labels.
# Image patch patch_192.0.tif saved in ../data/patch\train/images.
# Label patch patch_192.0.tif saved in ../data/patch\train/labels.
# Image patch patch_193.0.tif saved in ../data/patch\train/images.
# Label patch patch_193.0.tif saved in ../data/patch\train/labels.
# Image patch patch_194.0.tif saved in ../data/patch\validation/images.
# Label patch patch_194.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_195.0.tif saved in ../data/patch\train/images.
# Label patch patch_195.0.tif saved in ../data/patch\train/labels.
# Image patch patch_196.0.tif saved in ../data/patch\train/images.
# Label patch patch_196.0.tif saved in ../data/patch\train/labels.
# Image patch patch_197.0.tif saved in ../data/patch\train/images.
# Label patch patch_197.0.tif saved in ../data/patch\train/labels.
# Image patch patch_198.0.tif saved in ../data/patch\validation/images.
# Label patch patch_198.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_199.0.tif saved in ../data/patch\train/images.
# Label patch patch_199.0.tif saved in ../data/patch\train/labels.
# Image patch patch_200.0.tif saved in ../data/patch\train/images.
# Label patch patch_200.0.tif saved in ../data/patch\train/labels.
# Image patch patch_201.0.tif saved in ../data/patch\train/images.
# Label patch patch_201.0.tif saved in ../data/patch\train/labels.
# Image patch patch_202.0.tif saved in ../data/patch\train/images.
# Label patch patch_202.0.tif saved in ../data/patch\train/labels.
# Image patch patch_203.0.tif saved in ../data/patch\train/images.
# Label patch patch_203.0.tif saved in ../data/patch\train/labels.
# Image patch patch_204.0.tif saved in ../data/patch\train/images.
# Label patch patch_204.0.tif saved in ../data/patch\train/labels.
# Image patch patch_205.0.tif saved in ../data/patch\train/images.
# Label patch patch_205.0.tif saved in ../data/patch\train/labels.
# Image patch patch_206.0.tif saved in ../data/patch\validation/images.
# Label patch patch_206.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_207.0.tif saved in ../data/patch\train/images.
# Label patch patch_207.0.tif saved in ../data/patch\train/labels.
# Image patch patch_208.0.tif saved in ../data/patch\train/images.
# Label patch patch_208.0.tif saved in ../data/patch\train/labels.
# Image patch patch_209.0.tif saved in ../data/patch\train/images.
# Label patch patch_209.0.tif saved in ../data/patch\train/labels.
# Image patch patch_210.0.tif saved in ../data/patch\validation/images.
# Label patch patch_210.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_211.0.tif saved in ../data/patch\validation/images.
# Label patch patch_211.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_212.0.tif saved in ../data/patch\train/images.
# Label patch patch_212.0.tif saved in ../data/patch\train/labels.
# Image patch patch_213.0.tif saved in ../data/patch\train/images.
# Label patch patch_213.0.tif saved in ../data/patch\train/labels.
# Image patch patch_214.0.tif saved in ../data/patch\train/images.
# Label patch patch_214.0.tif saved in ../data/patch\train/labels.
# Image patch patch_215.0.tif saved in ../data/patch\train/images.
# Label patch patch_215.0.tif saved in ../data/patch\train/labels.
# Image patch patch_216.0.tif saved in ../data/patch\validation/images.
# Label patch patch_216.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_217.0.tif saved in ../data/patch\train/images.
# Label patch patch_217.0.tif saved in ../data/patch\train/labels.
# Image patch patch_218.0.tif saved in ../data/patch\train/images.
# Label patch patch_218.0.tif saved in ../data/patch\train/labels.
# Image patch patch_219.0.tif saved in ../data/patch\train/images.
# Label patch patch_219.0.tif saved in ../data/patch\train/labels.
# Image patch patch_220.0.tif saved in ../data/patch\train/images.
# Label patch patch_220.0.tif saved in ../data/patch\train/labels.
# Image patch patch_223.0.tif saved in ../data/patch\train/images.
# Label patch patch_223.0.tif saved in ../data/patch\train/labels.
# Image patch patch_224.0.tif saved in ../data/patch\train/images.
# Label patch patch_224.0.tif saved in ../data/patch\train/labels.
# Image patch patch_225.0.tif saved in ../data/patch\train/images.
# Label patch patch_225.0.tif saved in ../data/patch\train/labels.
# Image patch patch_226.0.tif saved in ../data/patch\train/images.
# Label patch patch_226.0.tif saved in ../data/patch\train/labels.
# Image patch patch_227.0.tif saved in ../data/patch\train/images.
# Label patch patch_227.0.tif saved in ../data/patch\train/labels.
# Image patch patch_228.0.tif saved in ../data/patch\train/images.
# Label patch patch_228.0.tif saved in ../data/patch\train/labels.
# Image patch patch_229.0.tif saved in ../data/patch\test/images.
# Label patch patch_229.0.tif saved in ../data/patch\test/labels.
# Image patch patch_230.0.tif saved in ../data/patch\train/images.
# Label patch patch_230.0.tif saved in ../data/patch\train/labels.
# Image patch patch_231.0.tif saved in ../data/patch\train/images.
# Label patch patch_231.0.tif saved in ../data/patch\train/labels.
# Image patch patch_232.0.tif saved in ../data/patch\validation/images.
# Label patch patch_232.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_233.0.tif saved in ../data/patch\validation/images.
# Label patch patch_233.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_234.0.tif saved in ../data/patch\train/images.
# Label patch patch_234.0.tif saved in ../data/patch\train/labels.
# Image patch patch_235.0.tif saved in ../data/patch\train/images.
# Label patch patch_235.0.tif saved in ../data/patch\train/labels.
# Image patch patch_236.0.tif saved in ../data/patch\validation/images.
# Label patch patch_236.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_237.0.tif saved in ../data/patch\validation/images.
# Label patch patch_237.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_238.0.tif saved in ../data/patch\train/images.
# Label patch patch_238.0.tif saved in ../data/patch\train/labels.
# Image patch patch_239.0.tif saved in ../data/patch\train/images.
# Label patch patch_239.0.tif saved in ../data/patch\train/labels.
# Image patch patch_240.0.tif saved in ../data/patch\train/images.
# Label patch patch_240.0.tif saved in ../data/patch\train/labels.
# Image patch patch_241.0.tif saved in ../data/patch\validation/images.
# Label patch patch_241.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_242.0.tif saved in ../data/patch\train/images.
# Label patch patch_242.0.tif saved in ../data/patch\train/labels.
# Image patch patch_243.0.tif saved in ../data/patch\train/images.
# Label patch patch_243.0.tif saved in ../data/patch\train/labels.
# Image patch patch_244.0.tif saved in ../data/patch\train/images.
# Label patch patch_244.0.tif saved in ../data/patch\train/labels.
# Image patch patch_245.0.tif saved in ../data/patch\train/images.
# Label patch patch_245.0.tif saved in ../data/patch\train/labels.
# Image patch patch_246.0.tif saved in ../data/patch\train/images.
# Label patch patch_246.0.tif saved in ../data/patch\train/labels.
# Image patch patch_247.0.tif saved in ../data/patch\train/images.
# Label patch patch_247.0.tif saved in ../data/patch\train/labels.
# Image patch patch_248.0.tif saved in ../data/patch\train/images.
# Label patch patch_248.0.tif saved in ../data/patch\train/labels.
# Image patch patch_249.0.tif saved in ../data/patch\train/images.
# Label patch patch_249.0.tif saved in ../data/patch\train/labels.
# Image patch patch_250.0.tif saved in ../data/patch\train/images.
# Label patch patch_250.0.tif saved in ../data/patch\train/labels.
# Image patch patch_251.0.tif saved in ../data/patch\train/images.
# Label patch patch_251.0.tif saved in ../data/patch\train/labels.
# Image patch patch_252.0.tif saved in ../data/patch\train/images.
# Label patch patch_252.0.tif saved in ../data/patch\train/labels.
# Image patch patch_253.0.tif saved in ../data/patch\train/images.
# Label patch patch_253.0.tif saved in ../data/patch\train/labels.
# Image patch patch_254.0.tif saved in ../data/patch\train/images.
# Label patch patch_254.0.tif saved in ../data/patch\train/labels.
# Image patch patch_255.0.tif saved in ../data/patch\train/images.
# Label patch patch_255.0.tif saved in ../data/patch\train/labels.
# Image patch patch_256.0.tif saved in ../data/patch\train/images.
# Label patch patch_256.0.tif saved in ../data/patch\train/labels.
# Image patch patch_257.0.tif saved in ../data/patch\validation/images.
# Label patch patch_257.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_260.0.tif saved in ../data/patch\train/images.
# Label patch patch_260.0.tif saved in ../data/patch\train/labels.
# Image patch patch_261.0.tif saved in ../data/patch\validation/images.
# Label patch patch_261.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_262.0.tif saved in ../data/patch\train/images.
# Label patch patch_262.0.tif saved in ../data/patch\train/labels.
# Image patch patch_263.0.tif saved in ../data/patch\validation/images.
# Label patch patch_263.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_264.0.tif saved in ../data/patch\validation/images.
# Label patch patch_264.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_265.0.tif saved in ../data/patch\train/images.
# Label patch patch_265.0.tif saved in ../data/patch\train/labels.
# Image patch patch_266.0.tif saved in ../data/patch\train/images.
# Label patch patch_266.0.tif saved in ../data/patch\train/labels.
# Image patch patch_267.0.tif saved in ../data/patch\validation/images.
# Label patch patch_267.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_268.0.tif saved in ../data/patch\train/images.
# Label patch patch_268.0.tif saved in ../data/patch\train/labels.
# Image patch patch_269.0.tif saved in ../data/patch\train/images.
# Label patch patch_269.0.tif saved in ../data/patch\train/labels.
# Image patch patch_270.0.tif saved in ../data/patch\train/images.
# Label patch patch_270.0.tif saved in ../data/patch\train/labels.
# Image patch patch_271.0.tif saved in ../data/patch\validation/images.
# Label patch patch_271.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_272.0.tif saved in ../data/patch\train/images.
# Label patch patch_272.0.tif saved in ../data/patch\train/labels.
# Image patch patch_273.0.tif saved in ../data/patch\validation/images.
# Label patch patch_273.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_274.0.tif saved in ../data/patch\train/images.
# Label patch patch_274.0.tif saved in ../data/patch\train/labels.
# Image patch patch_275.0.tif saved in ../data/patch\train/images.
# Label patch patch_275.0.tif saved in ../data/patch\train/labels.
# Image patch patch_276.0.tif saved in ../data/patch\test/images.
# Label patch patch_276.0.tif saved in ../data/patch\test/labels.
# Image patch patch_277.0.tif saved in ../data/patch\train/images.
# Label patch patch_277.0.tif saved in ../data/patch\train/labels.
# Image patch patch_278.0.tif saved in ../data/patch\train/images.
# Label patch patch_278.0.tif saved in ../data/patch\train/labels.
# Image patch patch_279.0.tif saved in ../data/patch\test/images.
# Label patch patch_279.0.tif saved in ../data/patch\test/labels.
# Image patch patch_280.0.tif saved in ../data/patch\train/images.
# Label patch patch_280.0.tif saved in ../data/patch\train/labels.
# Image patch patch_281.0.tif saved in ../data/patch\train/images.
# Label patch patch_281.0.tif saved in ../data/patch\train/labels.
# Image patch patch_282.0.tif saved in ../data/patch\validation/images.
# Label patch patch_282.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_283.0.tif saved in ../data/patch\train/images.
# Label patch patch_283.0.tif saved in ../data/patch\train/labels.
# Image patch patch_284.0.tif saved in ../data/patch\validation/images.
# Label patch patch_284.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_285.0.tif saved in ../data/patch\train/images.
# Label patch patch_285.0.tif saved in ../data/patch\train/labels.
# Image patch patch_286.0.tif saved in ../data/patch\train/images.
# Label patch patch_286.0.tif saved in ../data/patch\train/labels.
# Image patch patch_287.0.tif saved in ../data/patch\train/images.
# Label patch patch_287.0.tif saved in ../data/patch\train/labels.
# Image patch patch_288.0.tif saved in ../data/patch\validation/images.
# Label patch patch_288.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_289.0.tif saved in ../data/patch\validation/images.
# Label patch patch_289.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_290.0.tif saved in ../data/patch\train/images.
# Label patch patch_290.0.tif saved in ../data/patch\train/labels.
# Image patch patch_291.0.tif saved in ../data/patch\train/images.
# Label patch patch_291.0.tif saved in ../data/patch\train/labels.
# Image patch patch_292.0.tif saved in ../data/patch\train/images.
# Label patch patch_292.0.tif saved in ../data/patch\train/labels.
# Image patch patch_293.0.tif saved in ../data/patch\train/images.
# Label patch patch_293.0.tif saved in ../data/patch\train/labels.
# Image patch patch_294.0.tif saved in ../data/patch\train/images.
# Label patch patch_294.0.tif saved in ../data/patch\train/labels.
# Image patch patch_297.0.tif saved in ../data/patch\train/images.
# Label patch patch_297.0.tif saved in ../data/patch\train/labels.
# Image patch patch_298.0.tif saved in ../data/patch\test/images.
# Label patch patch_298.0.tif saved in ../data/patch\test/labels.
# Image patch patch_299.0.tif saved in ../data/patch\validation/images.
# Label patch patch_299.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_300.0.tif saved in ../data/patch\train/images.
# Label patch patch_300.0.tif saved in ../data/patch\train/labels.
# Image patch patch_301.0.tif saved in ../data/patch\train/images.
# Label patch patch_301.0.tif saved in ../data/patch\train/labels.
# Image patch patch_302.0.tif saved in ../data/patch\train/images.
# Label patch patch_302.0.tif saved in ../data/patch\train/labels.
# Image patch patch_303.0.tif saved in ../data/patch\test/images.
# Label patch patch_303.0.tif saved in ../data/patch\test/labels.
# Image patch patch_304.0.tif saved in ../data/patch\train/images.
# Label patch patch_304.0.tif saved in ../data/patch\train/labels.
# Image patch patch_305.0.tif saved in ../data/patch\validation/images.
# Label patch patch_305.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_306.0.tif saved in ../data/patch\train/images.
# Label patch patch_306.0.tif saved in ../data/patch\train/labels.
# Image patch patch_307.0.tif saved in ../data/patch\test/images.
# Label patch patch_307.0.tif saved in ../data/patch\test/labels.
# Image patch patch_308.0.tif saved in ../data/patch\test/images.
# Label patch patch_308.0.tif saved in ../data/patch\test/labels.
# Image patch patch_309.0.tif saved in ../data/patch\train/images.
# Label patch patch_309.0.tif saved in ../data/patch\train/labels.
# Image patch patch_310.0.tif saved in ../data/patch\train/images.
# Label patch patch_310.0.tif saved in ../data/patch\train/labels.
# Image patch patch_311.0.tif saved in ../data/patch\train/images.
# Label patch patch_311.0.tif saved in ../data/patch\train/labels.
# Image patch patch_312.0.tif saved in ../data/patch\validation/images.
# Label patch patch_312.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_313.0.tif saved in ../data/patch\train/images.
# Label patch patch_313.0.tif saved in ../data/patch\train/labels.
# Image patch patch_314.0.tif saved in ../data/patch\train/images.
# Label patch patch_314.0.tif saved in ../data/patch\train/labels.
# Image patch patch_315.0.tif saved in ../data/patch\train/images.
# Label patch patch_315.0.tif saved in ../data/patch\train/labels.
# Image patch patch_316.0.tif saved in ../data/patch\train/images.
# Label patch patch_316.0.tif saved in ../data/patch\train/labels.
# Image patch patch_317.0.tif saved in ../data/patch\train/images.
# Label patch patch_317.0.tif saved in ../data/patch\train/labels.
# Image patch patch_318.0.tif saved in ../data/patch\train/images.
# Label patch patch_318.0.tif saved in ../data/patch\train/labels.
# Image patch patch_319.0.tif saved in ../data/patch\train/images.
# Label patch patch_319.0.tif saved in ../data/patch\train/labels.
# Image patch patch_320.0.tif saved in ../data/patch\train/images.
# Label patch patch_320.0.tif saved in ../data/patch\train/labels.
# Image patch patch_321.0.tif saved in ../data/patch\validation/images.
# Label patch patch_321.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_322.0.tif saved in ../data/patch\train/images.
# Label patch patch_322.0.tif saved in ../data/patch\train/labels.
# Image patch patch_323.0.tif saved in ../data/patch\validation/images.
# Label patch patch_323.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_324.0.tif saved in ../data/patch\train/images.
# Label patch patch_324.0.tif saved in ../data/patch\train/labels.
# Image patch patch_325.0.tif saved in ../data/patch\train/images.
# Label patch patch_325.0.tif saved in ../data/patch\train/labels.
# Image patch patch_326.0.tif saved in ../data/patch\train/images.
# Label patch patch_326.0.tif saved in ../data/patch\train/labels.
# Image patch patch_327.0.tif saved in ../data/patch\train/images.
# Label patch patch_327.0.tif saved in ../data/patch\train/labels.
# Image patch patch_328.0.tif saved in ../data/patch\validation/images.
# Label patch patch_328.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_329.0.tif saved in ../data/patch\train/images.
# Label patch patch_329.0.tif saved in ../data/patch\train/labels.
# Image patch patch_330.0.tif saved in ../data/patch\validation/images.
# Label patch patch_330.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_331.0.tif saved in ../data/patch\validation/images.
# Label patch patch_331.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_334.0.tif saved in ../data/patch\test/images.
# Label patch patch_334.0.tif saved in ../data/patch\test/labels.
# Image patch patch_335.0.tif saved in ../data/patch\validation/images.
# Label patch patch_335.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_336.0.tif saved in ../data/patch\validation/images.
# Label patch patch_336.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_337.0.tif saved in ../data/patch\validation/images.
# Label patch patch_337.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_338.0.tif saved in ../data/patch\train/images.
# Label patch patch_338.0.tif saved in ../data/patch\train/labels.
# Image patch patch_339.0.tif saved in ../data/patch\train/images.
# Label patch patch_339.0.tif saved in ../data/patch\train/labels.
# Image patch patch_340.0.tif saved in ../data/patch\test/images.
# Label patch patch_340.0.tif saved in ../data/patch\test/labels.
# Image patch patch_341.0.tif saved in ../data/patch\train/images.
# Label patch patch_341.0.tif saved in ../data/patch\train/labels.
# Image patch patch_342.0.tif saved in ../data/patch\train/images.
# Label patch patch_342.0.tif saved in ../data/patch\train/labels.
# Image patch patch_343.0.tif saved in ../data/patch\train/images.
# Label patch patch_343.0.tif saved in ../data/patch\train/labels.
# Image patch patch_344.0.tif saved in ../data/patch\train/images.
# Label patch patch_344.0.tif saved in ../data/patch\train/labels.
# Image patch patch_345.0.tif saved in ../data/patch\test/images.
# Label patch patch_345.0.tif saved in ../data/patch\test/labels.
# Image patch patch_346.0.tif saved in ../data/patch\train/images.
# Label patch patch_346.0.tif saved in ../data/patch\train/labels.
# Image patch patch_347.0.tif saved in ../data/patch\train/images.
# Label patch patch_347.0.tif saved in ../data/patch\train/labels.
# Image patch patch_348.0.tif saved in ../data/patch\train/images.
# Label patch patch_348.0.tif saved in ../data/patch\train/labels.
# Image patch patch_349.0.tif saved in ../data/patch\train/images.
# Label patch patch_349.0.tif saved in ../data/patch\train/labels.
# Image patch patch_350.0.tif saved in ../data/patch\validation/images.
# Label patch patch_350.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_351.0.tif saved in ../data/patch\train/images.
# Label patch patch_351.0.tif saved in ../data/patch\train/labels.
# Image patch patch_352.0.tif saved in ../data/patch\train/images.
# Label patch patch_352.0.tif saved in ../data/patch\train/labels.
# Image patch patch_353.0.tif saved in ../data/patch\train/images.
# Label patch patch_353.0.tif saved in ../data/patch\train/labels.
# Image patch patch_354.0.tif saved in ../data/patch\train/images.
# Label patch patch_354.0.tif saved in ../data/patch\train/labels.
# Image patch patch_355.0.tif saved in ../data/patch\train/images.
# Label patch patch_355.0.tif saved in ../data/patch\train/labels.
# Image patch patch_356.0.tif saved in ../data/patch\validation/images.
# Label patch patch_356.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_357.0.tif saved in ../data/patch\train/images.
# Label patch patch_357.0.tif saved in ../data/patch\train/labels.
# Image patch patch_358.0.tif saved in ../data/patch\train/images.
# Label patch patch_358.0.tif saved in ../data/patch\train/labels.
# Image patch patch_359.0.tif saved in ../data/patch\train/images.
# Label patch patch_359.0.tif saved in ../data/patch\train/labels.
# Image patch patch_360.0.tif saved in ../data/patch\train/images.
# Label patch patch_360.0.tif saved in ../data/patch\train/labels.
# Image patch patch_361.0.tif saved in ../data/patch\train/images.
# Label patch patch_361.0.tif saved in ../data/patch\train/labels.
# Image patch patch_362.0.tif saved in ../data/patch\train/images.
# Label patch patch_362.0.tif saved in ../data/patch\train/labels.
# Image patch patch_363.0.tif saved in ../data/patch\train/images.
# Label patch patch_363.0.tif saved in ../data/patch\train/labels.
# Image patch patch_364.0.tif saved in ../data/patch\train/images.
# Label patch patch_364.0.tif saved in ../data/patch\train/labels.
# Image patch patch_365.0.tif saved in ../data/patch\train/images.
# Label patch patch_365.0.tif saved in ../data/patch\train/labels.
# Image patch patch_366.0.tif saved in ../data/patch\validation/images.
# Label patch patch_366.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_367.0.tif saved in ../data/patch\train/images.
# Label patch patch_367.0.tif saved in ../data/patch\train/labels.
# Image patch patch_368.0.tif saved in ../data/patch\validation/images.
# Label patch patch_368.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_371.0.tif saved in ../data/patch\train/images.
# Label patch patch_371.0.tif saved in ../data/patch\train/labels.
# Image patch patch_372.0.tif saved in ../data/patch\validation/images.
# Label patch patch_372.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_373.0.tif saved in ../data/patch\train/images.
# Label patch patch_373.0.tif saved in ../data/patch\train/labels.
# Image patch patch_374.0.tif saved in ../data/patch\train/images.
# Label patch patch_374.0.tif saved in ../data/patch\train/labels.
# Image patch patch_375.0.tif saved in ../data/patch\validation/images.
# Label patch patch_375.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_376.0.tif saved in ../data/patch\test/images.
# Label patch patch_376.0.tif saved in ../data/patch\test/labels.
# Image patch patch_377.0.tif saved in ../data/patch\train/images.
# Label patch patch_377.0.tif saved in ../data/patch\train/labels.
# Image patch patch_378.0.tif saved in ../data/patch\train/images.
# Label patch patch_378.0.tif saved in ../data/patch\train/labels.
# Image patch patch_379.0.tif saved in ../data/patch\train/images.
# Label patch patch_379.0.tif saved in ../data/patch\train/labels.
# Image patch patch_380.0.tif saved in ../data/patch\train/images.
# Label patch patch_380.0.tif saved in ../data/patch\train/labels.
# Image patch patch_381.0.tif saved in ../data/patch\train/images.
# Label patch patch_381.0.tif saved in ../data/patch\train/labels.
# Image patch patch_382.0.tif saved in ../data/patch\test/images.
# Label patch patch_382.0.tif saved in ../data/patch\test/labels.
# Image patch patch_383.0.tif saved in ../data/patch\train/images.
# Label patch patch_383.0.tif saved in ../data/patch\train/labels.
# Image patch patch_384.0.tif saved in ../data/patch\train/images.
# Label patch patch_384.0.tif saved in ../data/patch\train/labels.
# Image patch patch_385.0.tif saved in ../data/patch\train/images.
# Label patch patch_385.0.tif saved in ../data/patch\train/labels.
# Image patch patch_386.0.tif saved in ../data/patch\validation/images.
# Label patch patch_386.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_387.0.tif saved in ../data/patch\train/images.
# Label patch patch_387.0.tif saved in ../data/patch\train/labels.
# Image patch patch_388.0.tif saved in ../data/patch\validation/images.
# Label patch patch_388.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_389.0.tif saved in ../data/patch\validation/images.
# Label patch patch_389.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_390.0.tif saved in ../data/patch\train/images.
# Label patch patch_390.0.tif saved in ../data/patch\train/labels.
# Image patch patch_391.0.tif saved in ../data/patch\train/images.
# Label patch patch_391.0.tif saved in ../data/patch\train/labels.
# Image patch patch_392.0.tif saved in ../data/patch\validation/images.
# Label patch patch_392.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_393.0.tif saved in ../data/patch\train/images.
# Label patch patch_393.0.tif saved in ../data/patch\train/labels.
# Image patch patch_394.0.tif saved in ../data/patch\train/images.
# Label patch patch_394.0.tif saved in ../data/patch\train/labels.
# Image patch patch_395.0.tif saved in ../data/patch\validation/images.
# Label patch patch_395.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_396.0.tif saved in ../data/patch\train/images.
# Label patch patch_396.0.tif saved in ../data/patch\train/labels.
# Image patch patch_397.0.tif saved in ../data/patch\train/images.
# Label patch patch_397.0.tif saved in ../data/patch\train/labels.
# Image patch patch_398.0.tif saved in ../data/patch\train/images.
# Label patch patch_398.0.tif saved in ../data/patch\train/labels.
# Image patch patch_399.0.tif saved in ../data/patch\train/images.
# Label patch patch_399.0.tif saved in ../data/patch\train/labels.
# Image patch patch_400.0.tif saved in ../data/patch\train/images.
# Label patch patch_400.0.tif saved in ../data/patch\train/labels.
# Image patch patch_401.0.tif saved in ../data/patch\train/images.
# Label patch patch_401.0.tif saved in ../data/patch\train/labels.
# Image patch patch_402.0.tif saved in ../data/patch\train/images.
# Label patch patch_402.0.tif saved in ../data/patch\train/labels.
# Image patch patch_403.0.tif saved in ../data/patch\validation/images.
# Label patch patch_403.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_404.0.tif saved in ../data/patch\train/images.
# Label patch patch_404.0.tif saved in ../data/patch\train/labels.
# Image patch patch_405.0.tif saved in ../data/patch\test/images.
# Label patch patch_405.0.tif saved in ../data/patch\test/labels.
# Image patch patch_408.0.tif saved in ../data/patch\train/images.
# Label patch patch_408.0.tif saved in ../data/patch\train/labels.
# Image patch patch_409.0.tif saved in ../data/patch\train/images.
# Label patch patch_409.0.tif saved in ../data/patch\train/labels.
# Image patch patch_410.0.tif saved in ../data/patch\train/images.
# Label patch patch_410.0.tif saved in ../data/patch\train/labels.
# Image patch patch_411.0.tif saved in ../data/patch\train/images.
# Label patch patch_411.0.tif saved in ../data/patch\train/labels.
# Image patch patch_412.0.tif saved in ../data/patch\train/images.
# Label patch patch_412.0.tif saved in ../data/patch\train/labels.
# Image patch patch_413.0.tif saved in ../data/patch\train/images.
# Label patch patch_413.0.tif saved in ../data/patch\train/labels.
# Image patch patch_414.0.tif saved in ../data/patch\train/images.
# Label patch patch_414.0.tif saved in ../data/patch\train/labels.
# Image patch patch_415.0.tif saved in ../data/patch\train/images.
# Label patch patch_415.0.tif saved in ../data/patch\train/labels.
# Image patch patch_416.0.tif saved in ../data/patch\train/images.
# Label patch patch_416.0.tif saved in ../data/patch\train/labels.
# Image patch patch_417.0.tif saved in ../data/patch\train/images.
# Label patch patch_417.0.tif saved in ../data/patch\train/labels.
# Image patch patch_418.0.tif saved in ../data/patch\train/images.
# Label patch patch_418.0.tif saved in ../data/patch\train/labels.
# Image patch patch_419.0.tif saved in ../data/patch\train/images.
# Label patch patch_419.0.tif saved in ../data/patch\train/labels.
# Image patch patch_420.0.tif saved in ../data/patch\train/images.
# Label patch patch_420.0.tif saved in ../data/patch\train/labels.
# Image patch patch_421.0.tif saved in ../data/patch\test/images.
# Label patch patch_421.0.tif saved in ../data/patch\test/labels.
# Image patch patch_422.0.tif saved in ../data/patch\train/images.
# ...
# Label patch patch_1206.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1207.0.tif saved in ../data/patch\train/images.
# Label patch patch_1207.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1208.0.tif saved in ../data/patch\train/images.
# Label patch patch_1208.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1209.0.tif saved in ../data/patch\train/images.
# Label patch patch_1209.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1210.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1210.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1211.0.tif saved in ../data/patch\train/images.
# Label patch patch_1211.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1212.0.tif saved in ../data/patch\train/images.
# Label patch patch_1212.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1213.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1213.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1214.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1214.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1215.0.tif saved in ../data/patch\train/images.
# Label patch patch_1215.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1216.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1216.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1217.0.tif saved in ../data/patch\train/images.
# Label patch patch_1217.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1218.0.tif saved in ../data/patch\train/images.
# Label patch patch_1218.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1219.0.tif saved in ../data/patch\train/images.
# Label patch patch_1219.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1222.0.tif saved in ../data/patch\train/images.
# Label patch patch_1222.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1223.0.tif saved in ../data/patch\train/images.
# Label patch patch_1223.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1224.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1224.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1225.0.tif saved in ../data/patch\train/images.
# Label patch patch_1225.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1226.0.tif saved in ../data/patch\train/images.
# Label patch patch_1226.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1227.0.tif saved in ../data/patch\train/images.
# Label patch patch_1227.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1228.0.tif saved in ../data/patch\train/images.
# Label patch patch_1228.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1229.0.tif saved in ../data/patch\train/images.
# Label patch patch_1229.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1230.0.tif saved in ../data/patch\train/images.
# Label patch patch_1230.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1231.0.tif saved in ../data/patch\train/images.
# Label patch patch_1231.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1232.0.tif saved in ../data/patch\test/images.
# Label patch patch_1232.0.tif saved in ../data/patch\test/labels.
# Image patch patch_1233.0.tif saved in ../data/patch\train/images.
# Label patch patch_1233.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1234.0.tif saved in ../data/patch\train/images.
# Label patch patch_1234.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1235.0.tif saved in ../data/patch\train/images.
# Label patch patch_1235.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1236.0.tif saved in ../data/patch\train/images.
# Label patch patch_1236.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1237.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1237.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1238.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1238.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1239.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1239.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1240.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1240.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1241.0.tif saved in ../data/patch\train/images.
# Label patch patch_1241.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1242.0.tif saved in ../data/patch\train/images.
# Label patch patch_1242.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1243.0.tif saved in ../data/patch\test/images.
# Label patch patch_1243.0.tif saved in ../data/patch\test/labels.
# Image patch patch_1244.0.tif saved in ../data/patch\train/images.
# Label patch patch_1244.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1245.0.tif saved in ../data/patch\train/images.
# Label patch patch_1245.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1246.0.tif saved in ../data/patch\train/images.
# Label patch patch_1246.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1247.0.tif saved in ../data/patch\train/images.
# Label patch patch_1247.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1248.0.tif saved in ../data/patch\train/images.
# Label patch patch_1248.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1249.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1249.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1250.0.tif saved in ../data/patch\train/images.
# Label patch patch_1250.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1251.0.tif saved in ../data/patch\train/images.
# Label patch patch_1251.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1252.0.tif saved in ../data/patch\train/images.
# Label patch patch_1252.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1253.0.tif saved in ../data/patch\train/images.
# Label patch patch_1253.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1254.0.tif saved in ../data/patch\train/images.
# Label patch patch_1254.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1255.0.tif saved in ../data/patch\train/images.
# Label patch patch_1255.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1256.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1256.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1259.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1259.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1260.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1260.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1261.0.tif saved in ../data/patch\train/images.
# Label patch patch_1261.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1262.0.tif saved in ../data/patch\train/images.
# Label patch patch_1262.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1263.0.tif saved in ../data/patch\train/images.
# Label patch patch_1263.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1264.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1264.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1265.0.tif saved in ../data/patch\train/images.
# Label patch patch_1265.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1266.0.tif saved in ../data/patch\train/images.
# Label patch patch_1266.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1267.0.tif saved in ../data/patch\train/images.
# Label patch patch_1267.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1268.0.tif saved in ../data/patch\train/images.
# Label patch patch_1268.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1269.0.tif saved in ../data/patch\train/images.
# Label patch patch_1269.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1270.0.tif saved in ../data/patch\test/images.
# Label patch patch_1270.0.tif saved in ../data/patch\test/labels.
# Image patch patch_1271.0.tif saved in ../data/patch\train/images.
# Label patch patch_1271.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1272.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1272.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1273.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1273.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1274.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1274.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1275.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1275.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1276.0.tif saved in ../data/patch\train/images.
# Label patch patch_1276.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1277.0.tif saved in ../data/patch\train/images.
# Label patch patch_1277.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1278.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1278.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1279.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1279.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1280.0.tif saved in ../data/patch\train/images.
# Label patch patch_1280.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1281.0.tif saved in ../data/patch\train/images.
# Label patch patch_1281.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1282.0.tif saved in ../data/patch\train/images.
# Label patch patch_1282.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1283.0.tif saved in ../data/patch\train/images.
# Label patch patch_1283.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1284.0.tif saved in ../data/patch\train/images.
# Label patch patch_1284.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1285.0.tif saved in ../data/patch\train/images.
# Label patch patch_1285.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1286.0.tif saved in ../data/patch\train/images.
# Label patch patch_1286.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1287.0.tif saved in ../data/patch\train/images.
# Label patch patch_1287.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1288.0.tif saved in ../data/patch\train/images.
# Label patch patch_1288.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1289.0.tif saved in ../data/patch\test/images.
# Label patch patch_1289.0.tif saved in ../data/patch\test/labels.
# Image patch patch_1290.0.tif saved in ../data/patch\train/images.
# Label patch patch_1290.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1291.0.tif saved in ../data/patch\train/images.
# Label patch patch_1291.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1292.0.tif saved in ../data/patch\train/images.
# Label patch patch_1292.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1293.0.tif saved in ../data/patch\test/images.
# Label patch patch_1293.0.tif saved in ../data/patch\test/labels.
# Image patch patch_1296.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1296.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1297.0.tif saved in ../data/patch\train/images.
# Label patch patch_1297.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1298.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1298.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1299.0.tif saved in ../data/patch\train/images.
# Label patch patch_1299.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1300.0.tif saved in ../data/patch\train/images.
# Label patch patch_1300.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1301.0.tif saved in ../data/patch\train/images.
# Label patch patch_1301.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1302.0.tif saved in ../data/patch\train/images.
# Label patch patch_1302.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1303.0.tif saved in ../data/patch\train/images.
# Label patch patch_1303.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1304.0.tif saved in ../data/patch\train/images.
# Label patch patch_1304.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1305.0.tif saved in ../data/patch\train/images.
# Label patch patch_1305.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1306.0.tif saved in ../data/patch\train/images.
# Label patch patch_1306.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1307.0.tif saved in ../data/patch\train/images.
# Label patch patch_1307.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1308.0.tif saved in ../data/patch\train/images.
# Label patch patch_1308.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1309.0.tif saved in ../data/patch\train/images.
# Label patch patch_1309.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1310.0.tif saved in ../data/patch\train/images.
# Label patch patch_1310.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1311.0.tif saved in ../data/patch\train/images.
# Label patch patch_1311.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1312.0.tif saved in ../data/patch\train/images.
# Label patch patch_1312.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1313.0.tif saved in ../data/patch\train/images.
# Label patch patch_1313.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1314.0.tif saved in ../data/patch\train/images.
# Label patch patch_1314.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1315.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1315.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1316.0.tif saved in ../data/patch\train/images.
# Label patch patch_1316.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1317.0.tif saved in ../data/patch\train/images.
# Label patch patch_1317.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1318.0.tif saved in ../data/patch\train/images.
# Label patch patch_1318.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1319.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1319.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1320.0.tif saved in ../data/patch\validation/images.
# Label patch patch_1320.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1321.0.tif saved in ../data/patch\train/images.
# Label patch patch_1321.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1322.0.tif saved in ../data/patch\train/images.
# Label patch patch_1322.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1323.0.tif saved in ../data/patch\train/images.
# Label patch patch_1323.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1324.0.tif saved in ../data/patch\train/images.
# Label patch patch_1324.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1325.0.tif saved in ../data/patch\train/images.
# Label patch patch_1325.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1326.0.tif saved in ../data/patch\train/images.
# Label patch patch_1326.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1327.0.tif saved in ../data/patch\test/images.
# Label patch patch_1327.0.tif saved in ../data/patch\test/labels.
# Image patch patch_1328.0.tif saved in ../data/patch\train/images.
# Label patch patch_1328.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1329.0.tif saved in ../data/patch\train/images.
# Label patch patch_1329.0.tif saved in ../data/patch\train/labels.
# Image patch patch_1330.0.tif saved in ../data/patch\train/images.
# Label patch patch_1330.0.tif saved in ../data/patch\train/labels.
# Patch and label extraction completed, and distribution performed.

# %% [markdown]
# Step 2 : Images pre-processing

# %%
# Normalization
def normalize_img(img):
    return img / np.max(img)

# Function to read .tif files and convert them into tensors
def load_data(image_dir, mask_dir):
    images = []
    masks = []
    for img_file in os.listdir(image_dir):
        if img_file.endswith('.tif') or img_file.endswith('.tiff'):
            img_path = os.path.join(image_dir, img_file)
            mask_path = os.path.join(mask_dir, img_file)
            
            # Read images and masks
            img = tiff.imread(img_path).astype(np.float32)
            mask = tiff.imread(mask_path).astype(np.uint8)
            
            img = normalize_img(img)
            
            images.append(img)
            masks.append(mask)
    
    # Convert the lists into numpy arrays
    images = np.array(images)
    masks = np.array(masks)
    
    # Convert numpy arrays into tensors
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    masks = tf.convert_to_tensor(masks, dtype=tf.uint8)
    
    return images, masks

# %%
train_image_dir = '../data/patch/train/images'
train_mask_dir = '../data/patch/train/labels'
val_image_dir = '../data/patch/validation/images/'
val_mask_dir = '../data/patch/validation/labels'


# Load and transform the training data
train_images, train_masks = load_data(train_image_dir, train_mask_dir)
val_images, val_masks = load_data(val_image_dir, val_mask_dir)

print(f'Shape of training images: {train_images.shape}')
print(f'Shape of training labels: {train_masks.shape}')

# Check the pixel values of the images
print(f'Minimum and maximum values of the training images: {tf.reduce_min(train_images).numpy()}, {tf.reduce_max(train_images).numpy()}')
print(f'Minimum and maximum values of the training labels: {tf.reduce_min(train_masks).numpy()}, {tf.reduce_max(train_masks).numpy()}')

print(f'Minimum and maximum values of the validation images: {tf.reduce_min(val_images).numpy()}, {tf.reduce_max(val_images).numpy()}')
print(f'Minimum and maximum values of the validation labels: {tf.reduce_min(val_masks).numpy()}, {tf.reduce_max(val_masks).numpy()}')
# Out:
# Shape of training images: (918, 224, 224, 4)
# Shape of training labels: (918, 224, 224)
# Minimum and maximum values of the training images: 3.3804909094214963e-07, 1.0
# Minimum and maximum values of the training labels: 0, 4
# Minimum and maximum values of the validation images: 1.302852297158097e-06, 1.0
# Minimum and maximum values of the validation labels: 0, 4

# %% [markdown]
# Step 3 : Train of the U-Net Model

# %%
def unet_advanced(input_shape, num_classes=6):
    inputs = Input(input_shape)
    
    # Encodeur
    conv1 = Conv2D(64, 3, padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, 3, padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.5)(pool1)

    conv2 = Conv2D(128, 3, padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, 3, padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.5)(pool2)
    
    conv3 = Conv2D(256, 3, padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, 3, padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)
    
    conv4 = Conv2D(512, 3, padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, 3, padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.5)(pool4)
    
    conv5 = Conv2D(1024, 3, padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, 3, padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)

    up6 = UpSampling2D(size=(2, 2))(conv5)
    merge6 = Concatenate()([conv4, up6])
    conv6 = Conv2D(512, 3, padding='same')(merge6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, 3, padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    merge7 = Concatenate()([conv3, up7])
    conv7 = Conv2D(256, 3, padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, 3, padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    merge8 = Concatenate()([conv2, up8])
    conv8 = Conv2D(128, 3, padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, 3, padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    
    up9 = UpSampling2D(size=(2, 2))(conv8)
    merge9 = Concatenate()([conv1, up9])
    conv9 = Conv2D(64, 3, padding='same')(merge9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, 3, padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)

    outputs = Conv2D(num_classes, 1, activation='softmax')(conv9)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Define the parameters
img_height = 224
img_width = 224
num_channels = 4  # Variable to select the number of input channels
num_classes = 5   # Here is the number of classes you need to predict +1
batch_size = 4   # Reduce the batch size to decrease memory usage

# Initialize the U-Net model
input_shape = (img_height, img_width, num_channels)
model = unet_advanced(input_shape, num_classes=num_classes)
model.summary()

# Define the callback to save the best epoch
saved_model_path = "../saved_model"
checkpoint_cb = ModelCheckpoint(
    filepath=saved_model_path,  # Path to save the best model
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_format="tf",  # Ensure SavedModel format
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_images,
    train_masks,
    batch_size=batch_size,
    epochs=50,
    validation_data=(val_images, val_masks),
    callbacks=[checkpoint_cb]
)

print(f"The best model has been saved in SavedModel format at {saved_model_path}.")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 4  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  2368        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 224, 224, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 224, 224, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['activation_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 112, 112, 64  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 12  73856       ['dropout[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 112, 112, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 112, 112, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['activation_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 56, 56, 128)  0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 256)  295168      ['dropout_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 56, 56, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['activation_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 28, 28, 256)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 512)  1180160     ['dropout_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 28, 28, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 28, 28, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0          ['activation_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 14, 14, 512)  0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 1024  4719616     ['dropout_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 14, 14, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 14, 14, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 14, 14, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 28, 28, 1024  0           ['activation_9[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 28, 28, 1536  0           ['activation_7[0][0]',
#                                 )                                 'up_sampling2d[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 56, 56, 512)  0          ['activation_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 768)  0           ['activation_5[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 256)  1769728     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_13[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 112, 112, 25  0          ['activation_13[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 38  0           ['activation_3[0][0]',
#                                 4)                                'up_sampling2d_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 112, 112, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 112, 112, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 112, 112, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 112, 112, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 224, 224, 12  0          ['activation_15[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 19  0           ['activation_1[0][0]',
#                                 2)                                'up_sampling2d_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 224, 224, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 224, 224, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 224, 224, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 224, 224, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 224, 224, 5)  325         ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,403,333
# Trainable params: 31,391,557
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# Epoch 1/50
# 106/230 [============>.................] - ETA: 11:09 - loss: 0.6222 - accuracy: 0.8496

# %%
# Cell modified from original file due with problems with kernel crashing when plotting accuracy metrics

# Create a DataFrame with the metric values
metrics = pd.DataFrame({
    'Epoch': list(range(1, len(history.history['accuracy']) + 1)),
    'Train Accuracy': history.history['accuracy'],
    'Validation Accuracy': history.history['val_accuracy'],
    'Train Loss': history.history['loss'],
    'Validation Loss': history.history['val_loss']
})

# Save to Excel
metrics.to_excel('../results/metric_values.xlsx', index=False)

# %% [markdown]
# Step 4 : Displaying results

# %%
# Normalize the image
def normalize_img(img):
    return img / np.max(img)

# Load a test image and keep the geo-referencing information
def load_test_image(image_path):
    img = tiff.imread(image_path).astype(np.float32)
    img = normalize_img(img)
    img = np.expand_dims(img, axis=0)
    
    # Read the geo-referencing info (e.g., transform and CRS)
    with rasterio.open(image_path) as src:
        transform = src.transform
        crs = src.crs
        
    return img, transform, crs

# Load a test label
def load_test_mask(mask_path):
    mask = tiff.imread(mask_path).astype(np.uint8)
    return mask

# Paths to the test image and test label
test_image_path = '../data/patch/test/images/patch_1160.0.tif'  
test_mask_path = '../data/patch/test/labels/patch_1160.0.tif'

# Load the saved model (SavedModel format)
saved_model_path = '../saved_model'  # Path to the directory of the SavedModel
model = tf.keras.models.load_model(saved_model_path)

# Load and prepare the test image and test label
test_image, transform, crs = load_test_image(test_image_path)
test_mask = load_test_mask(test_mask_path)
print(f'Shape of test image: {test_image.shape}')
print(f'Shape of test mask: {test_mask.shape}')

# Predict the segmentation of the test image
prediction = model.predict(test_image)
predicted_mask = tf.argmax(prediction, axis=-1)
predicted_mask = tf.squeeze(predicted_mask).numpy()

# Save the predicted mask with geo-referencing
predicted_mask_path = '../results/prediction/predicted_mask.tif'  # Replace with the path where you want to save the predicted mask

# Write the predicted mask using rasterio, preserving the geo-referencing
with rasterio.open(test_image_path) as src:
    meta = src.meta  # Get the metadata (including the transform)
    meta.update(driver='GTiff', dtype=rasterio.uint8, count=1)  # Update the metadata to match the predicted mask's data type and single band count
    
    # Save the predicted mask as a georeferenced TIFF
    with rasterio.open(predicted_mask_path, 'w', **meta) as dst:
        dst.write(predicted_mask, 1)  # Write the predicted mask as the first band

print(f'Predicted mask saved as {predicted_mask_path}')
# Out:
# Shape of test image: (1, 224, 224, 4)
# Shape of test mask: (224, 224)
# 1/1 [==============================] - 1s 616ms/step
# Predicted mask saved as ../results/prediction/predicted_mask.tif
