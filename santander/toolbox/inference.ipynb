# %%
# !conda install -c conda-forge tqdm -y
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import os
import numpy as np
import rasterio
from rasterio.windows import Window
from rasterio.merge import merge
from osgeo import gdal
import subprocess
import tensorflow as tf
from tqdm import tqdm
import tempfile
from rasterio.enums import Resampling

# %%
def create_patches(input_tiff, output_dir, patch_size=224, overlap=125):
    """
    Splits a satellite image into patches with overlap and saves the patches.
    
    Args:
        input_tiff (str): Path to the input satellite image in TIFF format.
        output_dir (str): Directory where patches will be saved.
        patch_size (int): Size of each patch (default is 224x224 pixels).
        overlap (int): Number of pixels of overlap between patches.
    """
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Open the satellite image
    with rasterio.open(input_tiff) as src:
        width, height = src.width, src.height  # Get the image dimensions
        channels = src.count  # Get the number of bands (channels) in the image
        
        # Calculate the stride (the step size between patches)
        stride = patch_size - overlap
        
        # Initialize a counter to name the patches
        patch_count = 0
        
        # Loop through the image to extract patches
        for y in range(0, height - overlap, stride):
            for x in range(0, width - overlap, stride):
                # Check if the window stays within the image boundaries
                window = Window(x, y, patch_size, patch_size)
                if x + patch_size > width or y + patch_size > height:
                    continue
                
                # Read the data within the window (patch)
                patch = src.read(window=window)
                
                # Save the patch as a separate TIFF file
                patch_path = os.path.join(output_dir, f'patch_{patch_count}.tif')
                with rasterio.open(
                    patch_path,
                    'w',
                    driver='GTiff',
                    height=patch.shape[1],  # Height of the patch
                    width=patch.shape[2],   # Width of the patch
                    count=channels,         # Number of bands
                    dtype=patch.dtype,     # Data type of the patch
                    crs=src.crs,            # Coordinate Reference System
                    transform=rasterio.windows.transform(window, src.transform),  # Geospatial transform
                ) as dst:
                    dst.write(patch)  # Write the patch data
                
                patch_count += 1  # Increment patch counter
    
    # Print the number of patches created
    print(f"Splitting completed: {patch_count} patches saved in {output_dir}.")

# %%
# Example usage of the function
input_tiff = "../data/input/Imagev2.tif"  # Path to your satellite image
output_dir = "../data/patch"  # Directory to save the patches

# Call the function with a patch size of 224x224 and overlap of 32 pixels (you can change , if you increase the overlap the calculation time will be higher but with less artefacts)
create_patches(input_tiff, output_dir, patch_size=224, overlap=125)
# Out:
# Splitting completed: 2809 patches saved in ../data/patch.

# %%
# Image normalization function
def normalize_img(img):
    """Normalizes an image between 0 and 1."""
    return img / np.max(img)

# Function to load a test image with its georeferencing information
def load_test_image(image_path):
    """
    Loads a satellite image and normalizes it.
    
    Args:
        image_path (str): Path to the satellite image.
    
    Returns:
        img (ndarray): Normalized image.
        transform (Affine): Georeferencing transformation.
        crs (CRS): Coordinate reference system.
    """
    import tifffile as tiff
    img = tiff.imread(image_path).astype(np.float32)
    img = normalize_img(img)
    img = np.expand_dims(img, axis=0)  # Add a batch dimension
    
    # Read geospatial metadata
    with rasterio.open(image_path) as src:
        transform = src.transform
        crs = src.crs
        
    return img, transform, crs

# Function to predict all patches in a directory
def predict_patches(model_path, input_dir, output_dir):
    """
    Makes predictions for each patch in the input directory.
    
    Args:
        model_path (str): Path to the saved model (SavedModel).
        input_dir (str): Directory containing the input patches.
        output_dir (str): Directory to save the predictions.
    """
    # Load the model
    model = tf.keras.models.load_model(model_path)
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # List input patch files
    patch_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]
    
    for patch_file in patch_files:
        patch_path = os.path.join(input_dir, patch_file)
        
        # Load the test image
        test_image, transform, crs = load_test_image(patch_path)
        
        # Make the prediction
        prediction = model.predict(test_image)
        predicted_mask = tf.argmax(prediction, axis=-1)
        predicted_mask = tf.squeeze(predicted_mask).numpy().astype(np.uint8)
        
        # Define the output path for the predicted mask
        predicted_mask_path = os.path.join(output_dir, f"pred_{patch_file}")
        
        # Save the predicted mask with geospatial information
        with rasterio.open(patch_path) as src:
            meta = src.meta  # Get the metadata
            meta.update(driver='GTiff', dtype=rasterio.uint8, count=1)  # Adjust for the mask
            
            # Save the predicted mask
            with rasterio.open(predicted_mask_path, 'w', **meta) as dst:
                dst.write(predicted_mask, 1)  # Write the mask as the first band
        
        print(f"Prediction saved: {predicted_mask_path}")

# Parameters
model_path = '../saved_model'  # Path to your SavedModel
input_dir = '../data/patch'       # Directory containing the input patches
output_dir = '../results/prediction'  # Directory to save the predictions

# Run the prediction
predict_patches(model_path, input_dir, output_dir)
# Out:
# 1/1 [==============================] - 1s 539ms/step
# Prediction saved: ../results/prediction\pred_patch_0.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_1.tif
# 1/1 [==============================] - 0s 260ms/step
# Prediction saved: ../results/prediction\pred_patch_10.tif
# 1/1 [==============================] - 0s 284ms/step
# Prediction saved: ../results/prediction\pred_patch_100.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1000.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_1001.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_1002.tif
# 1/1 [==============================] - 0s 231ms/step
# Prediction saved: ../results/prediction\pred_patch_1003.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_1004.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_1005.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_1006.tif
# 1/1 [==============================] - 0s 253ms/step
# Prediction saved: ../results/prediction\pred_patch_1007.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1008.tif
# 1/1 [==============================] - 0s 248ms/step
# Prediction saved: ../results/prediction\pred_patch_1009.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_101.tif
# 1/1 [==============================] - 0s 260ms/step
# Prediction saved: ../results/prediction\pred_patch_1010.tif
# 1/1 [==============================] - 0s 228ms/step
# Prediction saved: ../results/prediction\pred_patch_1011.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1012.tif
# 1/1 [==============================] - 0s 222ms/step
# Prediction saved: ../results/prediction\pred_patch_1013.tif
# 1/1 [==============================] - 0s 254ms/step
# Prediction saved: ../results/prediction\pred_patch_1014.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1015.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_1016.tif
# 1/1 [==============================] - 0s 282ms/step
# Prediction saved: ../results/prediction\pred_patch_1017.tif
# 1/1 [==============================] - 0s 281ms/step
# Prediction saved: ../results/prediction\pred_patch_1018.tif
# 1/1 [==============================] - 0s 242ms/step
# Prediction saved: ../results/prediction\pred_patch_1019.tif
# 1/1 [==============================] - 0s 308ms/step
# Prediction saved: ../results/prediction\pred_patch_102.tif
# 1/1 [==============================] - 0s 254ms/step
# Prediction saved: ../results/prediction\pred_patch_1020.tif
# 1/1 [==============================] - 0s 223ms/step
# Prediction saved: ../results/prediction\pred_patch_1021.tif
# 1/1 [==============================] - 0s 241ms/step
# Prediction saved: ../results/prediction\pred_patch_1022.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_1023.tif
# 1/1 [==============================] - 0s 245ms/step
# Prediction saved: ../results/prediction\pred_patch_1024.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_1025.tif
# 1/1 [==============================] - 0s 227ms/step
# Prediction saved: ../results/prediction\pred_patch_1026.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_1027.tif
# 1/1 [==============================] - 0s 221ms/step
# Prediction saved: ../results/prediction\pred_patch_1028.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_1029.tif
# 1/1 [==============================] - 0s 232ms/step
# Prediction saved: ../results/prediction\pred_patch_103.tif
# 1/1 [==============================] - 0s 221ms/step
# Prediction saved: ../results/prediction\pred_patch_1030.tif
# 1/1 [==============================] - 0s 267ms/step
# Prediction saved: ../results/prediction\pred_patch_1031.tif
# 1/1 [==============================] - 0s 231ms/step
# Prediction saved: ../results/prediction\pred_patch_1032.tif
# 1/1 [==============================] - 0s 244ms/step
# Prediction saved: ../results/prediction\pred_patch_1033.tif
# 1/1 [==============================] - 0s 232ms/step
# Prediction saved: ../results/prediction\pred_patch_1034.tif
# 1/1 [==============================] - 0s 236ms/step
# Prediction saved: ../results/prediction\pred_patch_1035.tif
# 1/1 [==============================] - 0s 237ms/step
# Prediction saved: ../results/prediction\pred_patch_1036.tif
# 1/1 [==============================] - 0s 255ms/step
# Prediction saved: ../results/prediction\pred_patch_1037.tif
# 1/1 [==============================] - 0s 229ms/step
# Prediction saved: ../results/prediction\pred_patch_1038.tif
# 1/1 [==============================] - 0s 239ms/step
# Prediction saved: ../results/prediction\pred_patch_1039.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_104.tif
# 1/1 [==============================] - 0s 223ms/step
# Prediction saved: ../results/prediction\pred_patch_1040.tif
# 1/1 [==============================] - 0s 257ms/step
# Prediction saved: ../results/prediction\pred_patch_1041.tif
# 1/1 [==============================] - 0s 246ms/step
# Prediction saved: ../results/prediction\pred_patch_1042.tif
# 1/1 [==============================] - 0s 235ms/step
# Prediction saved: ../results/prediction\pred_patch_1043.tif
# 1/1 [==============================] - 0s 225ms/step
# Prediction saved: ../results/prediction\pred_patch_1044.tif
# 1/1 [==============================] - 0s 259ms/step
# Prediction saved: ../results/prediction\pred_patch_1045.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1046.tif
# 1/1 [==============================] - 0s 224ms/step
# Prediction saved: ../results/prediction\pred_patch_1047.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_1048.tif
# 1/1 [==============================] - 0s 227ms/step
# Prediction saved: ../results/prediction\pred_patch_1049.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_105.tif
# 1/1 [==============================] - 0s 238ms/step
# Prediction saved: ../results/prediction\pred_patch_1050.tif
# 1/1 [==============================] - 0s 260ms/step
# Prediction saved: ../results/prediction\pred_patch_1051.tif
# 1/1 [==============================] - 0s 245ms/step
# Prediction saved: ../results/prediction\pred_patch_1052.tif
# 1/1 [==============================] - 0s 228ms/step
# Prediction saved: ../results/prediction\pred_patch_1053.tif
# 1/1 [==============================] - 0s 222ms/step
# Prediction saved: ../results/prediction\pred_patch_1054.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_1055.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_1056.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_1057.tif
# 1/1 [==============================] - 0s 283ms/step
# Prediction saved: ../results/prediction\pred_patch_1058.tif
# 1/1 [==============================] - 0s 227ms/step
# Prediction saved: ../results/prediction\pred_patch_1059.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_106.tif
# 1/1 [==============================] - 0s 227ms/step
# Prediction saved: ../results/prediction\pred_patch_1060.tif
# 1/1 [==============================] - 0s 236ms/step
# Prediction saved: ../results/prediction\pred_patch_1061.tif
# 1/1 [==============================] - 0s 226ms/step
# Prediction saved: ../results/prediction\pred_patch_1062.tif
# 1/1 [==============================] - 0s 261ms/step
# Prediction saved: ../results/prediction\pred_patch_1063.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_1064.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1065.tif
# 1/1 [==============================] - 0s 233ms/step
# Prediction saved: ../results/prediction\pred_patch_1066.tif
# 1/1 [==============================] - 0s 234ms/step
# Prediction saved: ../results/prediction\pred_patch_1067.tif
# 1/1 [==============================] - 0s 245ms/step
# Prediction saved: ../results/prediction\pred_patch_1068.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_1069.tif
# 1/1 [==============================] - 0s 239ms/step
# Prediction saved: ../results/prediction\pred_patch_107.tif
# 1/1 [==============================] - 0s 245ms/step
# Prediction saved: ../results/prediction\pred_patch_1070.tif
# 1/1 [==============================] - 0s 255ms/step
# Prediction saved: ../results/prediction\pred_patch_1071.tif
# 1/1 [==============================] - 0s 227ms/step
# Prediction saved: ../results/prediction\pred_patch_1072.tif
# 1/1 [==============================] - 0s 239ms/step
# Prediction saved: ../results/prediction\pred_patch_1073.tif
# 1/1 [==============================] - 0s 257ms/step
# Prediction saved: ../results/prediction\pred_patch_1074.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_1075.tif
# 1/1 [==============================] - 0s 247ms/step
# Prediction saved: ../results/prediction\pred_patch_1076.tif
# 1/1 [==============================] - 0s 255ms/step
# Prediction saved: ../results/prediction\pred_patch_1077.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_1078.tif
# 1/1 [==============================] - 0s 257ms/step
# Prediction saved: ../results/prediction\pred_patch_1079.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_108.tif
# 1/1 [==============================] - 0s 262ms/step
# Prediction saved: ../results/prediction\pred_patch_1080.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_1081.tif
# 1/1 [==============================] - 0s 233ms/step
# Prediction saved: ../results/prediction\pred_patch_1082.tif
# 1/1 [==============================] - 0s 251ms/step
# Prediction saved: ../results/prediction\pred_patch_1083.tif
# 1/1 [==============================] - 0s 260ms/step
# Prediction saved: ../results/prediction\pred_patch_1084.tif
# 1/1 [==============================] - 0s 242ms/step
# Prediction saved: ../results/prediction\pred_patch_1085.tif
# 1/1 [==============================] - 0s 235ms/step
# Prediction saved: ../results/prediction\pred_patch_1086.tif
# 1/1 [==============================] - 0s 226ms/step
# Prediction saved: ../results/prediction\pred_patch_1087.tif
# 1/1 [==============================] - 0s 275ms/step
# Prediction saved: ../results/prediction\pred_patch_1088.tif
# 1/1 [==============================] - 0s 233ms/step
# Prediction saved: ../results/prediction\pred_patch_1089.tif
# 1/1 [==============================] - 0s 255ms/step
# Prediction saved: ../results/prediction\pred_patch_109.tif
# 1/1 [==============================] - 0s 285ms/step
# Prediction saved: ../results/prediction\pred_patch_1090.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_1091.tif
# 1/1 [==============================] - 0s 251ms/step
# Prediction saved: ../results/prediction\pred_patch_1092.tif
# 1/1 [==============================] - 0s 244ms/step
# Prediction saved: ../results/prediction\pred_patch_1093.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1094.tif
# 1/1 [==============================] - 0s 246ms/step
# Prediction saved: ../results/prediction\pred_patch_1095.tif
# 1/1 [==============================] - 0s 261ms/step
# Prediction saved: ../results/prediction\pred_patch_1096.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_1097.tif
# 1/1 [==============================] - 0s 253ms/step
# Prediction saved: ../results/prediction\pred_patch_1098.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1099.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_11.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_110.tif
# 1/1 [==============================] - 0s 236ms/step
# Prediction saved: ../results/prediction\pred_patch_1100.tif
# 1/1 [==============================] - 0s 235ms/step
# Prediction saved: ../results/prediction\pred_patch_1101.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_1102.tif
# 1/1 [==============================] - 0s 245ms/step
# Prediction saved: ../results/prediction\pred_patch_1103.tif
# 1/1 [==============================] - 0s 247ms/step
# Prediction saved: ../results/prediction\pred_patch_1104.tif
# 1/1 [==============================] - 0s 286ms/step
# Prediction saved: ../results/prediction\pred_patch_1105.tif
# 1/1 [==============================] - 0s 242ms/step
# Prediction saved: ../results/prediction\pred_patch_1106.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1107.tif
# 1/1 [==============================] - 0s 281ms/step
# Prediction saved: ../results/prediction\pred_patch_1108.tif
# 1/1 [==============================] - 0s 239ms/step
# Prediction saved: ../results/prediction\pred_patch_1109.tif
# 1/1 [==============================] - 0s 238ms/step
# Prediction saved: ../results/prediction\pred_patch_111.tif
# 1/1 [==============================] - 0s 239ms/step
# Prediction saved: ../results/prediction\pred_patch_1110.tif
# 1/1 [==============================] - 0s 282ms/step
# Prediction saved: ../results/prediction\pred_patch_1111.tif
# 1/1 [==============================] - 0s 267ms/step
# Prediction saved: ../results/prediction\pred_patch_1112.tif
# 1/1 [==============================] - 0s 236ms/step
# Prediction saved: ../results/prediction\pred_patch_1113.tif
# 1/1 [==============================] - 0s 254ms/step
# Prediction saved: ../results/prediction\pred_patch_1114.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1115.tif
# 1/1 [==============================] - 0s 236ms/step
# Prediction saved: ../results/prediction\pred_patch_1116.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1117.tif
# 1/1 [==============================] - 0s 267ms/step
# Prediction saved: ../results/prediction\pred_patch_1118.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1119.tif
# 1/1 [==============================] - 0s 296ms/step
# Prediction saved: ../results/prediction\pred_patch_112.tif
# 1/1 [==============================] - 0s 243ms/step
# Prediction saved: ../results/prediction\pred_patch_1120.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_1121.tif
# 1/1 [==============================] - 0s 247ms/step
# Prediction saved: ../results/prediction\pred_patch_1122.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1123.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_1124.tif
# 1/1 [==============================] - 0s 251ms/step
# Prediction saved: ../results/prediction\pred_patch_1125.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1126.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_1127.tif
# 1/1 [==============================] - 0s 280ms/step
# Prediction saved: ../results/prediction\pred_patch_1128.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1129.tif
# 1/1 [==============================] - 0s 239ms/step
# Prediction saved: ../results/prediction\pred_patch_113.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_1130.tif
# 1/1 [==============================] - 0s 242ms/step
# Prediction saved: ../results/prediction\pred_patch_1131.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_1132.tif
# 1/1 [==============================] - 0s 239ms/step
# Prediction saved: ../results/prediction\pred_patch_1133.tif
# 1/1 [==============================] - 0s 235ms/step
# Prediction saved: ../results/prediction\pred_patch_1134.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1135.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_1136.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_1137.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_1138.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_1139.tif
# 1/1 [==============================] - 0s 305ms/step
# Prediction saved: ../results/prediction\pred_patch_114.tif
# 1/1 [==============================] - 0s 289ms/step
# Prediction saved: ../results/prediction\pred_patch_1140.tif
# 1/1 [==============================] - 0s 264ms/step
# Prediction saved: ../results/prediction\pred_patch_1141.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_1142.tif
# 1/1 [==============================] - 0s 330ms/step
# Prediction saved: ../results/prediction\pred_patch_1143.tif
# 1/1 [==============================] - 1s 1s/step
# Prediction saved: ../results/prediction\pred_patch_1144.tif
# 1/1 [==============================] - 0s 405ms/step
# Prediction saved: ../results/prediction\pred_patch_1145.tif
# 1/1 [==============================] - 0s 355ms/step
# Prediction saved: ../results/prediction\pred_patch_1146.tif
# 1/1 [==============================] - 0s 369ms/step
# Prediction saved: ../results/prediction\pred_patch_1147.tif
# 1/1 [==============================] - 0s 345ms/step
# Prediction saved: ../results/prediction\pred_patch_1148.tif
# 1/1 [==============================] - 0s 380ms/step
# Prediction saved: ../results/prediction\pred_patch_1149.tif
# 1/1 [==============================] - 0s 341ms/step
# Prediction saved: ../results/prediction\pred_patch_115.tif
# 1/1 [==============================] - 0s 338ms/step
# Prediction saved: ../results/prediction\pred_patch_1150.tif
# 1/1 [==============================] - 0s 345ms/step
# Prediction saved: ../results/prediction\pred_patch_1151.tif
# 1/1 [==============================] - 0s 334ms/step
# Prediction saved: ../results/prediction\pred_patch_1152.tif
# 1/1 [==============================] - 0s 349ms/step
# Prediction saved: ../results/prediction\pred_patch_1153.tif
# 1/1 [==============================] - 0s 359ms/step
# Prediction saved: ../results/prediction\pred_patch_1154.tif
# 1/1 [==============================] - 1s 529ms/step
# Prediction saved: ../results/prediction\pred_patch_1155.tif
# 1/1 [==============================] - 0s 348ms/step
# Prediction saved: ../results/prediction\pred_patch_1156.tif
# 1/1 [==============================] - 0s 490ms/step
# Prediction saved: ../results/prediction\pred_patch_1157.tif
# 1/1 [==============================] - 0s 370ms/step
# Prediction saved: ../results/prediction\pred_patch_1158.tif
# 1/1 [==============================] - 1s 515ms/step
# Prediction saved: ../results/prediction\pred_patch_1159.tif
# 1/1 [==============================] - 0s 445ms/step
# Prediction saved: ../results/prediction\pred_patch_116.tif
# 1/1 [==============================] - 1s 634ms/step
# Prediction saved: ../results/prediction\pred_patch_1160.tif
# 1/1 [==============================] - 1s 529ms/step
# Prediction saved: ../results/prediction\pred_patch_1161.tif
# 1/1 [==============================] - 1s 511ms/step
# Prediction saved: ../results/prediction\pred_patch_1162.tif
# 1/1 [==============================] - 1s 656ms/step
# Prediction saved: ../results/prediction\pred_patch_1163.tif
# 1/1 [==============================] - 0s 419ms/step
# Prediction saved: ../results/prediction\pred_patch_1164.tif
# 1/1 [==============================] - 0s 364ms/step
# Prediction saved: ../results/prediction\pred_patch_1165.tif
# 1/1 [==============================] - 0s 438ms/step
# Prediction saved: ../results/prediction\pred_patch_1166.tif
# 1/1 [==============================] - 0s 325ms/step
# Prediction saved: ../results/prediction\pred_patch_1167.tif
# 1/1 [==============================] - 0s 303ms/step
# Prediction saved: ../results/prediction\pred_patch_1168.tif
# 1/1 [==============================] - 0s 314ms/step
# Prediction saved: ../results/prediction\pred_patch_1169.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_117.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_1170.tif
# 1/1 [==============================] - 0s 300ms/step
# Prediction saved: ../results/prediction\pred_patch_1171.tif
# 1/1 [==============================] - 0s 290ms/step
# Prediction saved: ../results/prediction\pred_patch_1172.tif
# 1/1 [==============================] - 0s 317ms/step
# Prediction saved: ../results/prediction\pred_patch_1173.tif
# 1/1 [==============================] - 0s 310ms/step
# Prediction saved: ../results/prediction\pred_patch_1174.tif
# 1/1 [==============================] - 0s 315ms/step
# Prediction saved: ../results/prediction\pred_patch_1175.tif
# 1/1 [==============================] - 0s 340ms/step
# Prediction saved: ../results/prediction\pred_patch_1176.tif
# 1/1 [==============================] - 0s 301ms/step
# Prediction saved: ../results/prediction\pred_patch_1177.tif
# 1/1 [==============================] - 0s 325ms/step
# Prediction saved: ../results/prediction\pred_patch_1178.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_1179.tif
# 1/1 [==============================] - 0s 330ms/step
# Prediction saved: ../results/prediction\pred_patch_118.tif
# 1/1 [==============================] - 0s 494ms/step
# Prediction saved: ../results/prediction\pred_patch_1180.tif
# 1/1 [==============================] - 0s 358ms/step
# Prediction saved: ../results/prediction\pred_patch_1181.tif
# 1/1 [==============================] - 0s 333ms/step
# Prediction saved: ../results/prediction\pred_patch_1182.tif
# 1/1 [==============================] - 0s 349ms/step
# Prediction saved: ../results/prediction\pred_patch_1183.tif
# 1/1 [==============================] - 0s 320ms/step
# Prediction saved: ../results/prediction\pred_patch_1184.tif
# 1/1 [==============================] - 0s 317ms/step
# Prediction saved: ../results/prediction\pred_patch_1185.tif
# 1/1 [==============================] - 0s 293ms/step
# Prediction saved: ../results/prediction\pred_patch_1186.tif
# 1/1 [==============================] - 0s 284ms/step
# Prediction saved: ../results/prediction\pred_patch_1187.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_1188.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_1189.tif
# 1/1 [==============================] - 0s 335ms/step
# Prediction saved: ../results/prediction\pred_patch_119.tif
# 1/1 [==============================] - 0s 395ms/step
# Prediction saved: ../results/prediction\pred_patch_1190.tif
# 1/1 [==============================] - 0s 341ms/step
# Prediction saved: ../results/prediction\pred_patch_1191.tif
# 1/1 [==============================] - 0s 330ms/step
# Prediction saved: ../results/prediction\pred_patch_1192.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_1193.tif
# 1/1 [==============================] - 0s 353ms/step
# Prediction saved: ../results/prediction\pred_patch_1194.tif
# 1/1 [==============================] - 0s 284ms/step
# Prediction saved: ../results/prediction\pred_patch_1195.tif
# 1/1 [==============================] - 0s 412ms/step
# Prediction saved: ../results/prediction\pred_patch_1196.tif
# 1/1 [==============================] - 0s 390ms/step
# Prediction saved: ../results/prediction\pred_patch_1197.tif
# 1/1 [==============================] - 0s 373ms/step
# Prediction saved: ../results/prediction\pred_patch_1198.tif
# 1/1 [==============================] - 0s 370ms/step
# Prediction saved: ../results/prediction\pred_patch_1199.tif
# 1/1 [==============================] - 0s 360ms/step
# Prediction saved: ../results/prediction\pred_patch_12.tif
# 1/1 [==============================] - 0s 381ms/step
# Prediction saved: ../results/prediction\pred_patch_120.tif
# 1/1 [==============================] - 0s 277ms/step
# Prediction saved: ../results/prediction\pred_patch_1200.tif
# 1/1 [==============================] - 0s 447ms/step
# Prediction saved: ../results/prediction\pred_patch_1201.tif
# 1/1 [==============================] - 0s 285ms/step
# Prediction saved: ../results/prediction\pred_patch_1202.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_1203.tif
# 1/1 [==============================] - 0s 399ms/step
# Prediction saved: ../results/prediction\pred_patch_1204.tif
# 1/1 [==============================] - 0s 354ms/step
# Prediction saved: ../results/prediction\pred_patch_1205.tif
# 1/1 [==============================] - 0s 345ms/step
# Prediction saved: ../results/prediction\pred_patch_1206.tif
# 1/1 [==============================] - 0s 314ms/step
# Prediction saved: ../results/prediction\pred_patch_1207.tif
# 1/1 [==============================] - 0s 472ms/step
# Prediction saved: ../results/prediction\pred_patch_1208.tif
# 1/1 [==============================] - 0s 352ms/step
# Prediction saved: ../results/prediction\pred_patch_1209.tif
# 1/1 [==============================] - 0s 316ms/step
# Prediction saved: ../results/prediction\pred_patch_121.tif
# 1/1 [==============================] - 0s 319ms/step
# Prediction saved: ../results/prediction\pred_patch_1210.tif
# 1/1 [==============================] - 0s 277ms/step
# Prediction saved: ../results/prediction\pred_patch_1211.tif
# 1/1 [==============================] - 0s 285ms/step
# Prediction saved: ../results/prediction\pred_patch_1212.tif
# 1/1 [==============================] - 0s 319ms/step
# Prediction saved: ../results/prediction\pred_patch_1213.tif
# 1/1 [==============================] - 0s 310ms/step
# Prediction saved: ../results/prediction\pred_patch_1214.tif
# 1/1 [==============================] - 0s 281ms/step
# Prediction saved: ../results/prediction\pred_patch_1215.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_1216.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_1217.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1218.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_1219.tif
# 1/1 [==============================] - 0s 285ms/step
# Prediction saved: ../results/prediction\pred_patch_122.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_1220.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_1221.tif
# 1/1 [==============================] - 0s 264ms/step
# Prediction saved: ../results/prediction\pred_patch_1222.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1223.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1224.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_1225.tif
# 1/1 [==============================] - 0s 369ms/step
# Prediction saved: ../results/prediction\pred_patch_1226.tif
# 1/1 [==============================] - 0s 385ms/step
# Prediction saved: ../results/prediction\pred_patch_1227.tif
# 1/1 [==============================] - 0s 312ms/step
# Prediction saved: ../results/prediction\pred_patch_1228.tif
# 1/1 [==============================] - 0s 328ms/step
# Prediction saved: ../results/prediction\pred_patch_1229.tif
# 1/1 [==============================] - 0s 431ms/step
# Prediction saved: ../results/prediction\pred_patch_123.tif
# 1/1 [==============================] - 0s 285ms/step
# Prediction saved: ../results/prediction\pred_patch_1230.tif
# 1/1 [==============================] - 0s 283ms/step
# Prediction saved: ../results/prediction\pred_patch_1231.tif
# 1/1 [==============================] - 0s 293ms/step
# Prediction saved: ../results/prediction\pred_patch_1232.tif
# 1/1 [==============================] - 0s 304ms/step
# Prediction saved: ../results/prediction\pred_patch_1233.tif
# 1/1 [==============================] - 0s 298ms/step
# Prediction saved: ../results/prediction\pred_patch_1234.tif
# 1/1 [==============================] - 0s 318ms/step
# Prediction saved: ../results/prediction\pred_patch_1235.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1236.tif
# 1/1 [==============================] - 0s 295ms/step
# Prediction saved: ../results/prediction\pred_patch_1237.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_1238.tif
# 1/1 [==============================] - 0s 312ms/step
# Prediction saved: ../results/prediction\pred_patch_1239.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_124.tif
# 1/1 [==============================] - 0s 288ms/step
# Prediction saved: ../results/prediction\pred_patch_1240.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1241.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_1242.tif
# 1/1 [==============================] - 0s 286ms/step
# Prediction saved: ../results/prediction\pred_patch_1243.tif
# 1/1 [==============================] - 0s 318ms/step
# Prediction saved: ../results/prediction\pred_patch_1244.tif
# 1/1 [==============================] - 0s 262ms/step
# Prediction saved: ../results/prediction\pred_patch_1245.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1246.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1247.tif
# 1/1 [==============================] - 0s 295ms/step
# Prediction saved: ../results/prediction\pred_patch_1248.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_1249.tif
# 1/1 [==============================] - 0s 289ms/step
# Prediction saved: ../results/prediction\pred_patch_125.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1250.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_1251.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_1252.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_1253.tif
# 1/1 [==============================] - 0s 254ms/step
# Prediction saved: ../results/prediction\pred_patch_1254.tif
# 1/1 [==============================] - 0s 308ms/step
# Prediction saved: ../results/prediction\pred_patch_1255.tif
# 1/1 [==============================] - 0s 262ms/step
# Prediction saved: ../results/prediction\pred_patch_1256.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_1257.tif
# 1/1 [==============================] - 0s 288ms/step
# Prediction saved: ../results/prediction\pred_patch_1258.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_1259.tif
# 1/1 [==============================] - 0s 253ms/step
# Prediction saved: ../results/prediction\pred_patch_126.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1260.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_1261.tif
# 1/1 [==============================] - 0s 305ms/step
# Prediction saved: ../results/prediction\pred_patch_1262.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1263.tif
# 1/1 [==============================] - 0s 313ms/step
# Prediction saved: ../results/prediction\pred_patch_1264.tif
# 1/1 [==============================] - 0s 267ms/step
# Prediction saved: ../results/prediction\pred_patch_1265.tif
# 1/1 [==============================] - 0s 300ms/step
# Prediction saved: ../results/prediction\pred_patch_1266.tif
# 1/1 [==============================] - 0s 438ms/step
# Prediction saved: ../results/prediction\pred_patch_1267.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_1268.tif
# 1/1 [==============================] - 0s 300ms/step
# Prediction saved: ../results/prediction\pred_patch_1269.tif
# 1/1 [==============================] - 0s 312ms/step
# Prediction saved: ../results/prediction\pred_patch_127.tif
# 1/1 [==============================] - 0s 294ms/step
# Prediction saved: ../results/prediction\pred_patch_1270.tif
# 1/1 [==============================] - 0s 434ms/step
# Prediction saved: ../results/prediction\pred_patch_1271.tif
# 1/1 [==============================] - 0s 338ms/step
# Prediction saved: ../results/prediction\pred_patch_1272.tif
# 1/1 [==============================] - 0s 317ms/step
# Prediction saved: ../results/prediction\pred_patch_1273.tif
# 1/1 [==============================] - 0s 340ms/step
# Prediction saved: ../results/prediction\pred_patch_1274.tif
# 1/1 [==============================] - 0s 379ms/step
# Prediction saved: ../results/prediction\pred_patch_1275.tif
# 1/1 [==============================] - 0s 296ms/step
# Prediction saved: ../results/prediction\pred_patch_1276.tif
# 1/1 [==============================] - 0s 314ms/step
# Prediction saved: ../results/prediction\pred_patch_1277.tif
# 1/1 [==============================] - 0s 294ms/step
# Prediction saved: ../results/prediction\pred_patch_1278.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1279.tif
# 1/1 [==============================] - 0s 273ms/step
# Prediction saved: ../results/prediction\pred_patch_128.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_1280.tif
# 1/1 [==============================] - 0s 267ms/step
# Prediction saved: ../results/prediction\pred_patch_1281.tif
# 1/1 [==============================] - 0s 364ms/step
# Prediction saved: ../results/prediction\pred_patch_1282.tif
# 1/1 [==============================] - 0s 368ms/step
# Prediction saved: ../results/prediction\pred_patch_1283.tif
# 1/1 [==============================] - 0s 362ms/step
# Prediction saved: ../results/prediction\pred_patch_1284.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_1285.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_1286.tif
# 1/1 [==============================] - 0s 291ms/step
# Prediction saved: ../results/prediction\pred_patch_1287.tif
# 1/1 [==============================] - 0s 309ms/step
# Prediction saved: ../results/prediction\pred_patch_1288.tif
# 1/1 [==============================] - 0s 282ms/step
# Prediction saved: ../results/prediction\pred_patch_1289.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_129.tif
# 1/1 [==============================] - 0s 291ms/step
# Prediction saved: ../results/prediction\pred_patch_1290.tif
# 1/1 [==============================] - 0s 283ms/step
# Prediction saved: ../results/prediction\pred_patch_1291.tif
# 1/1 [==============================] - 0s 251ms/step
# Prediction saved: ../results/prediction\pred_patch_1292.tif
# 1/1 [==============================] - 0s 289ms/step
# Prediction saved: ../results/prediction\pred_patch_1293.tif
# 1/1 [==============================] - 0s 289ms/step
# Prediction saved: ../results/prediction\pred_patch_1294.tif
# 1/1 [==============================] - 0s 303ms/step
# Prediction saved: ../results/prediction\pred_patch_1295.tif
# 1/1 [==============================] - 0s 277ms/step
# Prediction saved: ../results/prediction\pred_patch_1296.tif
# 1/1 [==============================] - 0s 292ms/step
# Prediction saved: ../results/prediction\pred_patch_1297.tif
# 1/1 [==============================] - 0s 264ms/step
# Prediction saved: ../results/prediction\pred_patch_1298.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_1299.tif
# 1/1 [==============================] - 0s 289ms/step
# Prediction saved: ../results/prediction\pred_patch_13.tif
# 1/1 [==============================] - 0s 282ms/step
# Prediction saved: ../results/prediction\pred_patch_130.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_1300.tif
# 1/1 [==============================] - 0s 254ms/step
# Prediction saved: ../results/prediction\pred_patch_1301.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_1302.tif
# 1/1 [==============================] - 0s 308ms/step
# Prediction saved: ../results/prediction\pred_patch_1303.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_1304.tif
# 1/1 [==============================] - 0s 318ms/step
# Prediction saved: ../results/prediction\pred_patch_1305.tif
# 1/1 [==============================] - 0s 291ms/step
# Prediction saved: ../results/prediction\pred_patch_1306.tif
# 1/1 [==============================] - 0s 257ms/step
# Prediction saved: ../results/prediction\pred_patch_1307.tif
# 1/1 [==============================] - 0s 281ms/step
# Prediction saved: ../results/prediction\pred_patch_1308.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_1309.tif
# 1/1 [==============================] - 0s 262ms/step
# Prediction saved: ../results/prediction\pred_patch_131.tif
# 1/1 [==============================] - 0s 282ms/step
# Prediction saved: ../results/prediction\pred_patch_1310.tif
# 1/1 [==============================] - 0s 330ms/step
# Prediction saved: ../results/prediction\pred_patch_1311.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_1312.tif
# 1/1 [==============================] - 0s 312ms/step
# Prediction saved: ../results/prediction\pred_patch_1313.tif
# 1/1 [==============================] - 0s 330ms/step
# Prediction saved: ../results/prediction\pred_patch_1314.tif
# 1/1 [==============================] - 0s 306ms/step
# Prediction saved: ../results/prediction\pred_patch_1315.tif
# 1/1 [==============================] - 0s 301ms/step
# Prediction saved: ../results/prediction\pred_patch_1316.tif
# 1/1 [==============================] - 0s 292ms/step
# Prediction saved: ../results/prediction\pred_patch_1317.tif
# 1/1 [==============================] - 0s 280ms/step
# Prediction saved: ../results/prediction\pred_patch_1318.tif
# 1/1 [==============================] - 0s 299ms/step
# Prediction saved: ../results/prediction\pred_patch_1319.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_132.tif
# 1/1 [==============================] - 0s 293ms/step
# Prediction saved: ../results/prediction\pred_patch_1320.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_1321.tif
# 1/1 [==============================] - 0s 264ms/step
# Prediction saved: ../results/prediction\pred_patch_1322.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_1323.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_1324.tif
# 1/1 [==============================] - 0s 386ms/step
# Prediction saved: ../results/prediction\pred_patch_1325.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_1326.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1327.tif
# 1/1 [==============================] - 0s 314ms/step
# Prediction saved: ../results/prediction\pred_patch_1328.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_1329.tif
# 1/1 [==============================] - 0s 320ms/step
# Prediction saved: ../results/prediction\pred_patch_133.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_1330.tif
# 1/1 [==============================] - 0s 289ms/step
# Prediction saved: ../results/prediction\pred_patch_1331.tif
# 1/1 [==============================] - 0s 291ms/step
# Prediction saved: ../results/prediction\pred_patch_1332.tif
# 1/1 [==============================] - 0s 329ms/step
# Prediction saved: ../results/prediction\pred_patch_1333.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_1334.tif
# 1/1 [==============================] - 0s 284ms/step
# Prediction saved: ../results/prediction\pred_patch_1335.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_1336.tif
# 1/1 [==============================] - 0s 282ms/step
# Prediction saved: ../results/prediction\pred_patch_1337.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_1338.tif
# 1/1 [==============================] - 0s 303ms/step
# Prediction saved: ../results/prediction\pred_patch_1339.tif
# 1/1 [==============================] - 0s 307ms/step
# Prediction saved: ../results/prediction\pred_patch_134.tif
# 1/1 [==============================] - 0s 291ms/step
# Prediction saved: ../results/prediction\pred_patch_1340.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_1341.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1342.tif
# 1/1 [==============================] - 0s 304ms/step
# Prediction saved: ../results/prediction\pred_patch_1343.tif
# 1/1 [==============================] - 0s 285ms/step
# Prediction saved: ../results/prediction\pred_patch_1344.tif
# 1/1 [==============================] - 0s 259ms/step
# Prediction saved: ../results/prediction\pred_patch_1345.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1346.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_1347.tif
# 1/1 [==============================] - 0s 281ms/step
# Prediction saved: ../results/prediction\pred_patch_1348.tif
# 1/1 [==============================] - 0s 275ms/step
# Prediction saved: ../results/prediction\pred_patch_1349.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_135.tif
# 1/1 [==============================] - 0s 262ms/step
# Prediction saved: ../results/prediction\pred_patch_1350.tif
# 1/1 [==============================] - 0s 295ms/step
# Prediction saved: ../results/prediction\pred_patch_1351.tif
# 1/1 [==============================] - 0s 275ms/step
# Prediction saved: ../results/prediction\pred_patch_1352.tif
# 1/1 [==============================] - 0s 294ms/step
# Prediction saved: ../results/prediction\pred_patch_1353.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_1354.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_1355.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_1356.tif
# 1/1 [==============================] - 0s 338ms/step
# Prediction saved: ../results/prediction\pred_patch_1357.tif
# 1/1 [==============================] - 0s 393ms/step
# Prediction saved: ../results/prediction\pred_patch_1358.tif
# 1/1 [==============================] - 0s 295ms/step
# Prediction saved: ../results/prediction\pred_patch_1359.tif
# 1/1 [==============================] - 0s 420ms/step
# Prediction saved: ../results/prediction\pred_patch_136.tif
# 1/1 [==============================] - 0s 345ms/step
# Prediction saved: ../results/prediction\pred_patch_1360.tif
# 1/1 [==============================] - 0s 336ms/step
# Prediction saved: ../results/prediction\pred_patch_1361.tif
# 1/1 [==============================] - 0s 335ms/step
# Prediction saved: ../results/prediction\pred_patch_1362.tif
# 1/1 [==============================] - 0s 333ms/step
# Prediction saved: ../results/prediction\pred_patch_1363.tif
# 1/1 [==============================] - 0s 354ms/step
# Prediction saved: ../results/prediction\pred_patch_1364.tif
# 1/1 [==============================] - 0s 305ms/step
# Prediction saved: ../results/prediction\pred_patch_1365.tif
# 1/1 [==============================] - 0s 302ms/step
# Prediction saved: ../results/prediction\pred_patch_1366.tif
# 1/1 [==============================] - 0s 299ms/step
# Prediction saved: ../results/prediction\pred_patch_1367.tif
# 1/1 [==============================] - 0s 309ms/step
# Prediction saved: ../results/prediction\pred_patch_1368.tif
# 1/1 [==============================] - 0s 331ms/step
# Prediction saved: ../results/prediction\pred_patch_1369.tif
# 1/1 [==============================] - 0s 298ms/step
# Prediction saved: ../results/prediction\pred_patch_137.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_1370.tif
# 1/1 [==============================] - 0s 299ms/step
# Prediction saved: ../results/prediction\pred_patch_1371.tif
# 1/1 [==============================] - 0s 294ms/step
# Prediction saved: ../results/prediction\pred_patch_1372.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1373.tif
# 1/1 [==============================] - 0s 288ms/step
# Prediction saved: ../results/prediction\pred_patch_1374.tif
# 1/1 [==============================] - 0s 303ms/step
# Prediction saved: ../results/prediction\pred_patch_1375.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_1376.tif
# 1/1 [==============================] - 0s 312ms/step
# Prediction saved: ../results/prediction\pred_patch_1377.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_1378.tif
# 1/1 [==============================] - 0s 299ms/step
# Prediction saved: ../results/prediction\pred_patch_1379.tif
# 1/1 [==============================] - 0s 331ms/step
# Prediction saved: ../results/prediction\pred_patch_138.tif
# ...
# Prediction saved: ../results/prediction\pred_patch_870.tif
# 1/1 [==============================] - 0s 248ms/step
# Prediction saved: ../results/prediction\pred_patch_871.tif
# 1/1 [==============================] - 0s 241ms/step
# Prediction saved: ../results/prediction\pred_patch_872.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_873.tif
# 1/1 [==============================] - 0s 280ms/step
# Prediction saved: ../results/prediction\pred_patch_874.tif
# 1/1 [==============================] - 0s 243ms/step
# Prediction saved: ../results/prediction\pred_patch_875.tif
# 1/1 [==============================] - 0s 273ms/step
# Prediction saved: ../results/prediction\pred_patch_876.tif
# 1/1 [==============================] - 0s 243ms/step
# Prediction saved: ../results/prediction\pred_patch_877.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_878.tif
# 1/1 [==============================] - 0s 247ms/step
# Prediction saved: ../results/prediction\pred_patch_879.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_88.tif
# 1/1 [==============================] - 0s 250ms/step
# Prediction saved: ../results/prediction\pred_patch_880.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_881.tif
# 1/1 [==============================] - 0s 247ms/step
# Prediction saved: ../results/prediction\pred_patch_882.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_883.tif
# 1/1 [==============================] - 0s 243ms/step
# Prediction saved: ../results/prediction\pred_patch_884.tif
# 1/1 [==============================] - 0s 242ms/step
# Prediction saved: ../results/prediction\pred_patch_885.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_886.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_887.tif
# 1/1 [==============================] - 0s 241ms/step
# Prediction saved: ../results/prediction\pred_patch_888.tif
# 1/1 [==============================] - 0s 294ms/step
# Prediction saved: ../results/prediction\pred_patch_889.tif
# 1/1 [==============================] - 0s 350ms/step
# Prediction saved: ../results/prediction\pred_patch_89.tif
# 1/1 [==============================] - 0s 316ms/step
# Prediction saved: ../results/prediction\pred_patch_890.tif
# 1/1 [==============================] - 0s 304ms/step
# Prediction saved: ../results/prediction\pred_patch_891.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_892.tif
# 1/1 [==============================] - 0s 360ms/step
# Prediction saved: ../results/prediction\pred_patch_893.tif
# 1/1 [==============================] - 0s 280ms/step
# Prediction saved: ../results/prediction\pred_patch_894.tif
# 1/1 [==============================] - 0s 309ms/step
# Prediction saved: ../results/prediction\pred_patch_895.tif
# 1/1 [==============================] - 0s 363ms/step
# Prediction saved: ../results/prediction\pred_patch_896.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_897.tif
# 1/1 [==============================] - 0s 307ms/step
# Prediction saved: ../results/prediction\pred_patch_898.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_899.tif
# 1/1 [==============================] - 0s 230ms/step
# Prediction saved: ../results/prediction\pred_patch_9.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_90.tif
# 1/1 [==============================] - 0s 290ms/step
# Prediction saved: ../results/prediction\pred_patch_900.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_901.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_902.tif
# 1/1 [==============================] - 0s 241ms/step
# Prediction saved: ../results/prediction\pred_patch_903.tif
# 1/1 [==============================] - 0s 267ms/step
# Prediction saved: ../results/prediction\pred_patch_904.tif
# 1/1 [==============================] - 0s 245ms/step
# Prediction saved: ../results/prediction\pred_patch_905.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_906.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_907.tif
# 1/1 [==============================] - 0s 262ms/step
# Prediction saved: ../results/prediction\pred_patch_908.tif
# 1/1 [==============================] - 0s 251ms/step
# Prediction saved: ../results/prediction\pred_patch_909.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_91.tif
# 1/1 [==============================] - 0s 245ms/step
# Prediction saved: ../results/prediction\pred_patch_910.tif
# 1/1 [==============================] - 0s 246ms/step
# Prediction saved: ../results/prediction\pred_patch_911.tif
# 1/1 [==============================] - 0s 241ms/step
# Prediction saved: ../results/prediction\pred_patch_912.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_913.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_914.tif
# 1/1 [==============================] - 0s 242ms/step
# Prediction saved: ../results/prediction\pred_patch_915.tif
# 1/1 [==============================] - 0s 246ms/step
# Prediction saved: ../results/prediction\pred_patch_916.tif
# 1/1 [==============================] - 0s 251ms/step
# Prediction saved: ../results/prediction\pred_patch_917.tif
# 1/1 [==============================] - 0s 287ms/step
# Prediction saved: ../results/prediction\pred_patch_918.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_919.tif
# 1/1 [==============================] - 0s 251ms/step
# Prediction saved: ../results/prediction\pred_patch_92.tif
# 1/1 [==============================] - 0s 247ms/step
# Prediction saved: ../results/prediction\pred_patch_920.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_921.tif
# 1/1 [==============================] - 0s 244ms/step
# Prediction saved: ../results/prediction\pred_patch_922.tif
# 1/1 [==============================] - 0s 248ms/step
# Prediction saved: ../results/prediction\pred_patch_923.tif
# 1/1 [==============================] - 0s 247ms/step
# Prediction saved: ../results/prediction\pred_patch_924.tif
# 1/1 [==============================] - 0s 246ms/step
# Prediction saved: ../results/prediction\pred_patch_925.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_926.tif
# 1/1 [==============================] - 0s 244ms/step
# Prediction saved: ../results/prediction\pred_patch_927.tif
# 1/1 [==============================] - 0s 261ms/step
# Prediction saved: ../results/prediction\pred_patch_928.tif
# 1/1 [==============================] - 0s 280ms/step
# Prediction saved: ../results/prediction\pred_patch_929.tif
# 1/1 [==============================] - 0s 297ms/step
# Prediction saved: ../results/prediction\pred_patch_93.tif
# 1/1 [==============================] - 0s 305ms/step
# Prediction saved: ../results/prediction\pred_patch_930.tif
# 1/1 [==============================] - 0s 248ms/step
# Prediction saved: ../results/prediction\pred_patch_931.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_932.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_933.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_934.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_935.tif
# 1/1 [==============================] - 0s 243ms/step
# Prediction saved: ../results/prediction\pred_patch_936.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_937.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_938.tif
# 1/1 [==============================] - 0s 248ms/step
# Prediction saved: ../results/prediction\pred_patch_939.tif
# 1/1 [==============================] - 0s 278ms/step
# Prediction saved: ../results/prediction\pred_patch_94.tif
# 1/1 [==============================] - 0s 264ms/step
# Prediction saved: ../results/prediction\pred_patch_940.tif
# 1/1 [==============================] - 0s 295ms/step
# Prediction saved: ../results/prediction\pred_patch_941.tif
# 1/1 [==============================] - 0s 248ms/step
# Prediction saved: ../results/prediction\pred_patch_942.tif
# 1/1 [==============================] - 0s 309ms/step
# Prediction saved: ../results/prediction\pred_patch_943.tif
# 1/1 [==============================] - 0s 263ms/step
# Prediction saved: ../results/prediction\pred_patch_944.tif
# 1/1 [==============================] - 0s 262ms/step
# Prediction saved: ../results/prediction\pred_patch_945.tif
# 1/1 [==============================] - 0s 280ms/step
# Prediction saved: ../results/prediction\pred_patch_946.tif
# 1/1 [==============================] - 0s 256ms/step
# Prediction saved: ../results/prediction\pred_patch_947.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_948.tif
# 1/1 [==============================] - 0s 283ms/step
# Prediction saved: ../results/prediction\pred_patch_949.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_95.tif
# 1/1 [==============================] - 0s 281ms/step
# Prediction saved: ../results/prediction\pred_patch_950.tif
# 1/1 [==============================] - 0s 259ms/step
# Prediction saved: ../results/prediction\pred_patch_951.tif
# 1/1 [==============================] - 0s 315ms/step
# Prediction saved: ../results/prediction\pred_patch_952.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_953.tif
# 1/1 [==============================] - 0s 276ms/step
# Prediction saved: ../results/prediction\pred_patch_954.tif
# 1/1 [==============================] - 0s 270ms/step
# Prediction saved: ../results/prediction\pred_patch_955.tif
# 1/1 [==============================] - 0s 265ms/step
# Prediction saved: ../results/prediction\pred_patch_956.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_957.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_958.tif
# 1/1 [==============================] - 0s 244ms/step
# Prediction saved: ../results/prediction\pred_patch_959.tif
# 1/1 [==============================] - 0s 284ms/step
# Prediction saved: ../results/prediction\pred_patch_96.tif
# 1/1 [==============================] - 0s 288ms/step
# Prediction saved: ../results/prediction\pred_patch_960.tif
# 1/1 [==============================] - 0s 246ms/step
# Prediction saved: ../results/prediction\pred_patch_961.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_962.tif
# 1/1 [==============================] - 0s 312ms/step
# Prediction saved: ../results/prediction\pred_patch_963.tif
# 1/1 [==============================] - 0s 246ms/step
# Prediction saved: ../results/prediction\pred_patch_964.tif
# 1/1 [==============================] - 0s 267ms/step
# Prediction saved: ../results/prediction\pred_patch_965.tif
# 1/1 [==============================] - 0s 257ms/step
# Prediction saved: ../results/prediction\pred_patch_966.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_967.tif
# 1/1 [==============================] - 0s 284ms/step
# Prediction saved: ../results/prediction\pred_patch_968.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_969.tif
# 1/1 [==============================] - 0s 252ms/step
# Prediction saved: ../results/prediction\pred_patch_97.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_970.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_971.tif
# 1/1 [==============================] - 0s 271ms/step
# Prediction saved: ../results/prediction\pred_patch_972.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_973.tif
# 1/1 [==============================] - 0s 300ms/step
# Prediction saved: ../results/prediction\pred_patch_974.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_975.tif
# 1/1 [==============================] - 0s 296ms/step
# Prediction saved: ../results/prediction\pred_patch_976.tif
# 1/1 [==============================] - 0s 279ms/step
# Prediction saved: ../results/prediction\pred_patch_977.tif
# 1/1 [==============================] - 0s 261ms/step
# Prediction saved: ../results/prediction\pred_patch_978.tif
# 1/1 [==============================] - 0s 292ms/step
# Prediction saved: ../results/prediction\pred_patch_979.tif
# 1/1 [==============================] - 0s 288ms/step
# Prediction saved: ../results/prediction\pred_patch_98.tif
# 1/1 [==============================] - 0s 275ms/step
# Prediction saved: ../results/prediction\pred_patch_980.tif
# 1/1 [==============================] - 0s 272ms/step
# Prediction saved: ../results/prediction\pred_patch_981.tif
# 1/1 [==============================] - 0s 240ms/step
# Prediction saved: ../results/prediction\pred_patch_982.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_983.tif
# 1/1 [==============================] - 0s 258ms/step
# Prediction saved: ../results/prediction\pred_patch_984.tif
# 1/1 [==============================] - 0s 293ms/step
# Prediction saved: ../results/prediction\pred_patch_985.tif
# 1/1 [==============================] - 0s 254ms/step
# Prediction saved: ../results/prediction\pred_patch_986.tif
# 1/1 [==============================] - 0s 269ms/step
# Prediction saved: ../results/prediction\pred_patch_987.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_988.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_989.tif
# 1/1 [==============================] - 0s 268ms/step
# Prediction saved: ../results/prediction\pred_patch_99.tif
# 1/1 [==============================] - 0s 260ms/step
# Prediction saved: ../results/prediction\pred_patch_990.tif
# 1/1 [==============================] - 0s 274ms/step
# Prediction saved: ../results/prediction\pred_patch_991.tif
# 1/1 [==============================] - 0s 299ms/step
# Prediction saved: ../results/prediction\pred_patch_992.tif
# 1/1 [==============================] - 0s 266ms/step
# Prediction saved: ../results/prediction\pred_patch_993.tif
# 1/1 [==============================] - 0s 281ms/step
# Prediction saved: ../results/prediction\pred_patch_994.tif
# 1/1 [==============================] - 0s 264ms/step
# Prediction saved: ../results/prediction\pred_patch_995.tif
# 1/1 [==============================] - 0s 292ms/step
# Prediction saved: ../results/prediction\pred_patch_996.tif
# 1/1 [==============================] - 0s 289ms/step
# Prediction saved: ../results/prediction\pred_patch_997.tif
# 1/1 [==============================] - 0s 248ms/step
# Prediction saved: ../results/prediction\pred_patch_998.tif
# 1/1 [==============================] - 0s 249ms/step
# Prediction saved: ../results/prediction\pred_patch_999.tif

# %%
def reconstruct_from_patches(input_dir, output_path, overlap=200, buffer_size=50):
    """
    Reconstructs a large-scale image from GeoTIFF patches with overlap handling.
    
    Args:
        input_dir (str): Directory containing the GeoTIFF patches
        output_path (str): Output path for the reconstructed image
        overlap (int): Number of pixels of overlap between patches
        buffer_size (int): Area to ignore at the edges of each patch to avoid artifacts
    """
    # List all GeoTIFF files in the directory
    patch_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.tif', '.tiff'))]
    if not patch_files:
        raise ValueError("No GeoTIFF files found in the input directory")

    # Load metadata from the first patch
    first_patch = os.path.join(input_dir, patch_files[0])
    with rasterio.open(first_patch) as src:
        meta = src.meta.copy()
        dtype = src.dtypes[0]
        count = src.count

    # Create a temporary directory for processed patches
    temp_dir = tempfile.mkdtemp()
    processed_patches = []

    print("Processing individual patches...")
    for patch_file in tqdm(patch_files):
        patch_path = os.path.join(input_dir, patch_file)
        temp_path = os.path.join(temp_dir, f"processed_{patch_file}")
        
        with rasterio.open(patch_path) as src:
            # Read the data with a reduced window to avoid borders
            height, width = src.shape
            window = Window(
                buffer_size, 
                buffer_size, 
                width - 2 * buffer_size, 
                height - 2 * buffer_size
            )
            
            # Read the data within the window
            data = src.read(window=window)
            
            # Compute the new transform for this window
            transform = src.window_transform(window)
            
            # Update metadata
            meta.update({
                'height': window.height,
                'width': window.width,
                'transform': transform
            })
            
            # Write the processed patch
            with rasterio.open(temp_path, 'w', **meta) as dst:
                dst.write(data)
        
        processed_patches.append(temp_path)

    print("Merging processed patches...")
    # Merge all processed patches
    src_files_to_mosaic = [rasterio.open(patch) for patch in processed_patches]
    mosaic, out_trans = merge(
        src_files_to_mosaic,
        method='first',  # Takes the first non-null value (avoids overlaps)
        resampling=Resampling.nearest
    )

    # Close all opened files
    for src in src_files_to_mosaic:
        src.close()

    # Update final metadata
    meta.update({
        'driver': 'GTiff',
        'height': mosaic.shape[1],
        'width': mosaic.shape[2],
        'transform': out_trans,
        'compress': 'lzw',
        'nodata': 8,
        'dtype': dtype,
        'count': count
    })

    print("Writing the final image...")
    # Write the final image
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(mosaic)

    # Clean up temporary files
    for patch in processed_patches:
        try:
            os.remove(patch)
        except:
            pass
    try:
        os.rmdir(temp_dir)
    except:
        pass

    print(f"Reconstruction completed. Image saved at: {output_path}")


if __name__ == "__main__":
    # Example usage
    input_directory = "../results/prediction" 
    output_file = "../results/prediction/reconstructed_image.tif"
    
    reconstruct_from_patches(
        input_dir=input_directory,
        output_path=output_file,
        overlap=125,  # Matches your description
        buffer_size=40  # Area to ignore at the borders
    )
# Out:
# Processing individual patches...
# 100%|██████████| 2810/2810 [00:45<00:00, 61.86it/s]
# Merging processed patches...
# Writing the final image...
# Reconstruction completed. Image saved at: ../results/prediction/reconstructed_image.tif
