# %% [markdown]
# Step 1 : Patch Extraction

# %%
import os
import numpy as np
import tifffile as tiff
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, BatchNormalization, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import rasterio
from rasterio.mask import mask
from rasterio.transform import from_origin
import geopandas as gpd
import cv2
import random

# %%
def extract_patches(image_path, label_path, shapefile_path, output_dir, train_ratio=0.5, val_ratio=0.25, test_ratio=0.25):
    
    with rasterio.open(image_path) as src_img:
        
        with rasterio.open(label_path) as src_lbl:
            
            grid = gpd.read_file(shapefile_path) #Load the satellite image, load the labels, and then the grid containing the patches. 
            
            train_img_dir = os.path.join(output_dir, 'train/images')
            val_img_dir = os.path.join(output_dir, 'validation/images')
            test_img_dir = os.path.join(output_dir, 'test/images')

            train_lbl_dir = os.path.join(output_dir, 'train/labels')
            val_lbl_dir = os.path.join(output_dir, 'validation/labels')
            test_lbl_dir = os.path.join(output_dir, 'test/labels')
            #Create the train, validation, and test directories if they do not already exist.
            
            for dir_path in [train_img_dir, val_img_dir, test_img_dir, train_lbl_dir, val_lbl_dir, test_lbl_dir]:
                if not os.path.exists(dir_path):
                    os.makedirs(dir_path)

            
            indices = list(grid.index)
            random.shuffle(indices)
            # Shuffle the patch indices for a random distribution
            
            num_patches = len(indices)
            
            #num_train = int(train_ratio * num_patches)
            #num_val = int(val_ratio * num_patches)
            #num_test = num_patches - num_train - num_val

            # Ensure we have at least 1 patch for each split
            num_train = max(1, int(train_ratio * num_patches))
            num_val = max(1, int(val_ratio * num_patches))
            num_test = max(1, num_patches - num_train - num_val)

            # Calculate the sizes of the train, validation, and test sets.
            
            train_indices = indices[:num_train]
            val_indices = indices[num_train:num_train + num_val]
            test_indices = indices[num_train + num_val:]

            
            def save_patch_and_label(patch, label, transform, output_img_subdir, output_lbl_subdir, patch_filename):
                
                patch_img_path = os.path.join(output_img_subdir, patch_filename)
                with rasterio.open(
                    patch_img_path, 'w',
                    driver='GTiff',
                    height=224, width=224,
                    count=4, dtype=patch.dtype, #Set the count variable according to the number of spectral bands you have.
                    crs=src_img.crs, transform=transform
                ) as dst_img:
                    dst_img.write(patch)
                print(f"Image patch {patch_filename} saved in {output_img_subdir}.")

                
                patch_lbl_path = os.path.join(output_lbl_subdir, patch_filename)
                with rasterio.open(
                    patch_lbl_path, 'w',
                    driver='GTiff',
                    height=224, width=224,
                    count=1, dtype=label.dtype,  # Single channel for labels
                    crs=src_lbl.crs, transform=transform
                ) as dst_lbl:
                    dst_lbl.write(label[0, :, :], 1)  # Correcting the write operation
                print(f"Label patch {patch_filename} saved in {output_lbl_subdir}.")

            
            for idx, row in grid.iterrows():
                geom = [row['geometry']]
                auto_value = row['AUTO']  # Column with unique identifiers

                # Extract the patch for the image
                patch_img, transform = mask(src_img, geom, crop=True)
                patch_lbl, _ = mask(src_lbl, geom, crop=True)

                # Check the patch size and resize if necessary (for the image and the label)
                height_img, width_img = patch_img.shape[1], patch_img.shape[2]
                height_lbl, width_lbl = patch_lbl.shape[1], patch_lbl.shape[2]
                
                if height_img != 224 or width_img != 224:
                    resized_patch_img = np.zeros((4, 224, 224), dtype=patch_img.dtype)
                    for i in range(4):
                        resized_patch_img[i] = cv2.resize(patch_img[i], (224, 224), interpolation=cv2.INTER_LINEAR)
                    patch_img = resized_patch_img
                
                if height_lbl != 224 or width_lbl != 224:
                    resized_patch_lbl = cv2.resize(patch_lbl[0], (224, 224), interpolation=cv2.INTER_NEAREST)
                    patch_lbl = resized_patch_lbl[np.newaxis, :, :]  # Add channel dimension
                
                # Determine the directory to save the patch
                patch_filename = f"patch_{auto_value}.tif"
                if idx in train_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, train_img_dir, train_lbl_dir, patch_filename)
                elif idx in val_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, val_img_dir, val_lbl_dir, patch_filename)
                elif idx in test_indices:
                    save_patch_and_label(patch_img, patch_lbl, transform, test_img_dir, test_lbl_dir, patch_filename)

    print("Patch and label extraction completed, and distribution performed.")

# %%
image_path = "../data/input/image_s2.tif"
label_path = "../data/input/label.tif"
shapefile_path = "../data/input/grid_2240.shp"
output_dir = "../data/patch"
extract_patches(image_path, label_path, shapefile_path, output_dir)
# Out:
# Image patch patch_0.0.tif saved in ../data/patch\validation/images.
# Label patch patch_0.0.tif saved in ../data/patch\validation/labels.
# Image patch patch_1.0.tif saved in ../data/patch\test/images.
# Label patch patch_1.0.tif saved in ../data/patch\test/labels.
# Image patch patch_2.0.tif saved in ../data/patch\train/images.
# Label patch patch_2.0.tif saved in ../data/patch\train/labels.
# Image patch patch_3.0.tif saved in ../data/patch\train/images.
# Label patch patch_3.0.tif saved in ../data/patch\train/labels.
# Patch and label extraction completed, and distribution performed.

# %% [markdown]
# Step 2 : Images pre-processing

# %%
# Normalization
def normalize_img(img):
    return img / np.max(img)

# Function to read .tif files and convert them into tensors
def load_data(image_dir, mask_dir):
    images = []
    masks = []
    for img_file in os.listdir(image_dir):
        if img_file.endswith('.tif') or img_file.endswith('.tiff'):
            img_path = os.path.join(image_dir, img_file)
            mask_path = os.path.join(mask_dir, img_file)
            
            # Read images and masks
            img = tiff.imread(img_path).astype(np.float32)
            mask = tiff.imread(mask_path).astype(np.uint8)
            
            img = normalize_img(img)
            
            images.append(img)
            masks.append(mask)
    
    # Convert the lists into numpy arrays
    images = np.array(images)
    masks = np.array(masks)
    
    # Convert numpy arrays into tensors
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    masks = tf.convert_to_tensor(masks, dtype=tf.uint8)
    
    return images, masks

# %%
train_image_dir = '../data/patch/train/images'
train_mask_dir = '../data/patch/train/labels'
val_image_dir = '../data/patch/validation/images/'
val_mask_dir = '../data/patch/validation/labels'


# Load and transform the training data
train_images, train_masks = load_data(train_image_dir, train_mask_dir)
val_images, val_masks = load_data(val_image_dir, val_mask_dir)

print(f'Shape of training images: {train_images.shape}')
print(f'Shape of training labels: {train_masks.shape}')

# Check the pixel values of the images
print(f'Minimum and maximum values of the training images: {tf.reduce_min(train_images).numpy()}, {tf.reduce_max(train_images).numpy()}')
print(f'Minimum and maximum values of the training labels: {tf.reduce_min(train_masks).numpy()}, {tf.reduce_max(train_masks).numpy()}')

print(f'Minimum and maximum values of the validation images: {tf.reduce_min(val_images).numpy()}, {tf.reduce_max(val_images).numpy()}')
print(f'Minimum and maximum values of the validation labels: {tf.reduce_min(val_masks).numpy()}, {tf.reduce_max(val_masks).numpy()}')
# Out:
# Shape of training images: (4, 224, 224, 4)
# Shape of training labels: (4, 224, 224)
# Minimum and maximum values of the training images: 0.00012124151544412598, 1.0
# Minimum and maximum values of the training labels: 0, 5
# Minimum and maximum values of the validation images: 0.0002689617977011949, 1.0
# Minimum and maximum values of the validation labels: 0, 5

# %% [markdown]
# Step 3 : Train of the U-Net Model

# %%
def unet_advanced(input_shape, num_classes=6):
    inputs = Input(input_shape)
    
    # Encodeur
    conv1 = Conv2D(64, 3, padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, 3, padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.5)(pool1)

    conv2 = Conv2D(128, 3, padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, 3, padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.5)(pool2)
    
    conv3 = Conv2D(256, 3, padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, 3, padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)
    
    conv4 = Conv2D(512, 3, padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, 3, padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.5)(pool4)
    
    conv5 = Conv2D(1024, 3, padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, 3, padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)

    up6 = UpSampling2D(size=(2, 2))(conv5)
    merge6 = Concatenate()([conv4, up6])
    conv6 = Conv2D(512, 3, padding='same')(merge6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, 3, padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    merge7 = Concatenate()([conv3, up7])
    conv7 = Conv2D(256, 3, padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, 3, padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    merge8 = Concatenate()([conv2, up8])
    conv8 = Conv2D(128, 3, padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, 3, padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    
    up9 = UpSampling2D(size=(2, 2))(conv8)
    merge9 = Concatenate()([conv1, up9])
    conv9 = Conv2D(64, 3, padding='same')(merge9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, 3, padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)

    outputs = Conv2D(num_classes, 1, activation='softmax')(conv9)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Define the parameters
img_height = 224
img_width = 224
num_channels = 4  # Variable to select the number of input channels
num_classes = 6   # Here is the number of classes you need to predict +1
batch_size = 4   # Reduce the batch size to decrease memory usage

# Initialize the U-Net model
input_shape = (img_height, img_width, num_channels)
model = unet_advanced(input_shape, num_classes=num_classes)
model.summary()

# Define the callback to save the best epoch
saved_model_path = "../saved_model"
checkpoint_cb = ModelCheckpoint(
    filepath=saved_model_path,  # Path to save the best model
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_format="tf",  # Ensure SavedModel format
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_images,
    train_masks,
    batch_size=batch_size,
    epochs=100,
    validation_data=(val_images, val_masks),
    callbacks=[checkpoint_cb]
)

print(f"The best model has been saved in SavedModel format at {saved_model_path}.")
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 4  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 224, 224, 64  2368        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 224, 224, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 224, 224, 64  36928       ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 224, 224, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 112, 112, 64  0          ['activation_19[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 112, 112, 64  0           ['max_pooling2d_4[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 12  73856       ['dropout_4[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 112, 112, 12  512        ['conv2d_21[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 112, 112, 12  147584      ['activation_20[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 112, 112, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 128)  0          ['activation_21[0][0]']
#
#  dropout_5 (Dropout)            (None, 56, 56, 128)  0           ['max_pooling2d_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 56, 56, 256)  295168      ['dropout_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 256)  0          ['activation_23[0][0]']
#
#  dropout_6 (Dropout)            (None, 28, 28, 256)  0           ['max_pooling2d_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 512)  1180160     ['dropout_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['activation_25[0][0]']
#
#  dropout_7 (Dropout)            (None, 14, 14, 512)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 1024  4719616     ['dropout_7[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 1024  9438208     ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 28, 28, 1024  0          ['activation_27[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 1536  0           ['activation_25[0][0]',
#                                 )                                 'up_sampling2d_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 512)  7078400     ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_29[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 56, 56, 512)  0          ['activation_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 768)  0           ['activation_23[0][0]',
#                                                                   'up_sampling2d_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 256)  1769728     ['concatenate_5[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_31[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 112, 112, 25  0          ['activation_31[0][0]']
#                                 6)
#
#  concatenate_6 (Concatenate)    (None, 112, 112, 38  0           ['activation_21[0][0]',
#                                 4)                                'up_sampling2d_6[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 112, 112, 12  442496      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_32 (BatchN  (None, 112, 112, 12  512        ['conv2d_33[0][0]']
#  ormalization)                  8)
#
#  activation_32 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_32[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 112, 112, 12  147584      ['activation_32[0][0]']
#                                 8)
#
#  batch_normalization_33 (BatchN  (None, 112, 112, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  activation_33 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_33[0][0]']
#                                 8)
#
#  up_sampling2d_7 (UpSampling2D)  (None, 224, 224, 12  0          ['activation_33[0][0]']
#                                 8)
#
#  concatenate_7 (Concatenate)    (None, 224, 224, 19  0           ['activation_19[0][0]',
#                                 2)                                'up_sampling2d_7[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 224, 224, 64  110656      ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 224, 224, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 224, 224, 64  36928       ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 224, 224, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 224, 224, 6)  390         ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 31,403,398
# Trainable params: 31,391,622
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 2.3470 - accuracy: 0.1843
# Epoch 1: val_loss improved from inf to 1.79193, saving model to ..\saved_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 19). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# INFO:tensorflow:Assets written to: ..\saved_model\assets
# 1/1 [==============================] - 24s 24s/step - loss: 2.3470 - accuracy: 0.1843 - val_loss: 1.7919 - val_accuracy: 0.1991
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7083 - accuracy: 0.4923
# Epoch 2: val_loss did not improve from 1.79193
# 1/1 [==============================] - 6s 6s/step - loss: 1.7083 - accuracy: 0.4923 - val_loss: 1.7960 - val_accuracy: 0.0954
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3240 - accuracy: 0.5636
# Epoch 3: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 1.3240 - accuracy: 0.5636 - val_loss: 1.8578 - val_accuracy: 0.0410
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0954 - accuracy: 0.6097
# Epoch 4: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 1.0954 - accuracy: 0.6097 - val_loss: 2.0560 - val_accuracy: 0.0207
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9566 - accuracy: 0.6399
# Epoch 5: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.9566 - accuracy: 0.6399 - val_loss: 2.4780 - val_accuracy: 0.0178
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8630 - accuracy: 0.7076
# Epoch 6: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.8630 - accuracy: 0.7076 - val_loss: 3.2110 - val_accuracy: 0.0175
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7982 - accuracy: 0.7311
# Epoch 7: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.7982 - accuracy: 0.7311 - val_loss: 4.5419 - val_accuracy: 0.0206
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7516 - accuracy: 0.7421
# Epoch 8: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.7516 - accuracy: 0.7421 - val_loss: 6.3847 - val_accuracy: 0.0210
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7148 - accuracy: 0.7524
# Epoch 9: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.7148 - accuracy: 0.7524 - val_loss: 8.3608 - val_accuracy: 0.0107
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.7589
# Epoch 10: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.6868 - accuracy: 0.7589 - val_loss: 9.7071 - val_accuracy: 0.0100
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6684 - accuracy: 0.7619
# Epoch 11: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.6684 - accuracy: 0.7619 - val_loss: 10.9718 - val_accuracy: 0.0094
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6499 - accuracy: 0.7668
# Epoch 12: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.6499 - accuracy: 0.7668 - val_loss: 11.4350 - val_accuracy: 0.0149
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.7717
# Epoch 13: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.6331 - accuracy: 0.7717 - val_loss: 11.8531 - val_accuracy: 0.0151
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6173 - accuracy: 0.7758
# Epoch 14: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.6173 - accuracy: 0.7758 - val_loss: 12.0774 - val_accuracy: 0.0064
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6051 - accuracy: 0.7800
# Epoch 15: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.6051 - accuracy: 0.7800 - val_loss: 12.7919 - val_accuracy: 0.0043
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5889 - accuracy: 0.7866
# Epoch 16: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.5889 - accuracy: 0.7866 - val_loss: 12.7200 - val_accuracy: 0.0065
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5783 - accuracy: 0.7928
# Epoch 17: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.5783 - accuracy: 0.7928 - val_loss: 12.0925 - val_accuracy: 0.0074
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5686 - accuracy: 0.7951
# Epoch 18: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.5686 - accuracy: 0.7951 - val_loss: 12.3703 - val_accuracy: 0.0060
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5589 - accuracy: 0.7972
# Epoch 19: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.5589 - accuracy: 0.7972 - val_loss: 12.0345 - val_accuracy: 0.0047
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5481 - accuracy: 0.7996
# Epoch 20: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.5481 - accuracy: 0.7996 - val_loss: 11.8632 - val_accuracy: 0.0054
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5379 - accuracy: 0.8028
# Epoch 21: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.5379 - accuracy: 0.8028 - val_loss: 11.3441 - val_accuracy: 0.0069
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5290 - accuracy: 0.8063
# Epoch 22: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.5290 - accuracy: 0.8063 - val_loss: 11.2832 - val_accuracy: 0.0199
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5219 - accuracy: 0.8097
# Epoch 23: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.5219 - accuracy: 0.8097 - val_loss: 11.6055 - val_accuracy: 0.0218
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5174 - accuracy: 0.8078
# Epoch 24: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.5174 - accuracy: 0.8078 - val_loss: 11.5853 - val_accuracy: 0.0233
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5071 - accuracy: 0.8122
# Epoch 25: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.5071 - accuracy: 0.8122 - val_loss: 10.9115 - val_accuracy: 0.0280
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5017 - accuracy: 0.8154
# Epoch 26: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.5017 - accuracy: 0.8154 - val_loss: 9.8326 - val_accuracy: 0.0281
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.8154
# Epoch 27: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.4958 - accuracy: 0.8154 - val_loss: 8.9828 - val_accuracy: 0.0282
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4870 - accuracy: 0.8185
# Epoch 28: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4870 - accuracy: 0.8185 - val_loss: 8.4942 - val_accuracy: 0.0281
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.8185
# Epoch 29: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4920 - accuracy: 0.8185 - val_loss: 7.2585 - val_accuracy: 0.0285
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.8177
# Epoch 30: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.4873 - accuracy: 0.8177 - val_loss: 6.8844 - val_accuracy: 0.0291
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4702 - accuracy: 0.8264
# Epoch 31: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4702 - accuracy: 0.8264 - val_loss: 6.1972 - val_accuracy: 0.0279
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4683 - accuracy: 0.8258
# Epoch 32: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4683 - accuracy: 0.8258 - val_loss: 5.2803 - val_accuracy: 0.0314
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.8250
# Epoch 33: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4657 - accuracy: 0.8250 - val_loss: 4.9893 - val_accuracy: 0.0323
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4660 - accuracy: 0.8240
# Epoch 34: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4660 - accuracy: 0.8240 - val_loss: 4.5763 - val_accuracy: 0.0320
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4553 - accuracy: 0.8300
# Epoch 35: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4553 - accuracy: 0.8300 - val_loss: 3.9218 - val_accuracy: 0.0343
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4552 - accuracy: 0.8289
# Epoch 36: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4552 - accuracy: 0.8289 - val_loss: 3.4894 - val_accuracy: 0.0657
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4516 - accuracy: 0.8318
# Epoch 37: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4516 - accuracy: 0.8318 - val_loss: 3.2141 - val_accuracy: 0.0540
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4499 - accuracy: 0.8319
# Epoch 38: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4499 - accuracy: 0.8319 - val_loss: 3.1193 - val_accuracy: 0.1341
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.8343
# Epoch 39: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4412 - accuracy: 0.8343 - val_loss: 3.2829 - val_accuracy: 0.0935
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4410 - accuracy: 0.8337
# Epoch 40: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4410 - accuracy: 0.8337 - val_loss: 3.6707 - val_accuracy: 0.0523
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4368 - accuracy: 0.8356
# Epoch 41: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4368 - accuracy: 0.8356 - val_loss: 3.1994 - val_accuracy: 0.1829
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8388
# Epoch 42: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4278 - accuracy: 0.8388 - val_loss: 2.6814 - val_accuracy: 0.2317
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4250 - accuracy: 0.8416
# Epoch 43: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4250 - accuracy: 0.8416 - val_loss: 2.4178 - val_accuracy: 0.2316
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8421
# Epoch 44: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4215 - accuracy: 0.8421 - val_loss: 2.3463 - val_accuracy: 0.2203
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.8430
# Epoch 45: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4180 - accuracy: 0.8430 - val_loss: 2.3040 - val_accuracy: 0.2291
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8435
# Epoch 46: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4148 - accuracy: 0.8435 - val_loss: 2.3110 - val_accuracy: 0.2290
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.8460
# Epoch 47: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4097 - accuracy: 0.8460 - val_loss: 2.3987 - val_accuracy: 0.2307
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.8448
# Epoch 48: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4094 - accuracy: 0.8448 - val_loss: 2.3749 - val_accuracy: 0.2312
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.8479
# Epoch 49: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.4034 - accuracy: 0.8479 - val_loss: 2.1767 - val_accuracy: 0.2421
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4026 - accuracy: 0.8470
# Epoch 50: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4026 - accuracy: 0.8470 - val_loss: 2.0574 - val_accuracy: 0.2425
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4000 - accuracy: 0.8487
# Epoch 51: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.4000 - accuracy: 0.8487 - val_loss: 2.0095 - val_accuracy: 0.2484
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3963 - accuracy: 0.8493
# Epoch 52: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3963 - accuracy: 0.8493 - val_loss: 1.9902 - val_accuracy: 0.2328
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8486
# Epoch 53: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3971 - accuracy: 0.8486 - val_loss: 2.0372 - val_accuracy: 0.2358
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3925 - accuracy: 0.8501
# Epoch 54: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3925 - accuracy: 0.8501 - val_loss: 2.1831 - val_accuracy: 0.2494
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8518
# Epoch 55: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3905 - accuracy: 0.8518 - val_loss: 2.3117 - val_accuracy: 0.2500
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3885 - accuracy: 0.8507
# Epoch 56: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3885 - accuracy: 0.8507 - val_loss: 2.1042 - val_accuracy: 0.2408
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3862 - accuracy: 0.8524
# Epoch 57: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3862 - accuracy: 0.8524 - val_loss: 2.0640 - val_accuracy: 0.2421
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3823 - accuracy: 0.8545
# Epoch 58: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3823 - accuracy: 0.8545 - val_loss: 2.0768 - val_accuracy: 0.2447
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3804 - accuracy: 0.8552
# Epoch 59: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3804 - accuracy: 0.8552 - val_loss: 2.1021 - val_accuracy: 0.2503
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.8559
# Epoch 60: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3777 - accuracy: 0.8559 - val_loss: 2.1048 - val_accuracy: 0.2455
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.8555
# Epoch 61: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3761 - accuracy: 0.8555 - val_loss: 2.0879 - val_accuracy: 0.2460
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3730 - accuracy: 0.8571
# Epoch 62: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3730 - accuracy: 0.8571 - val_loss: 2.0735 - val_accuracy: 0.2443
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8556
# Epoch 63: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3759 - accuracy: 0.8556 - val_loss: 2.0128 - val_accuracy: 0.2382
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8546
# Epoch 64: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3752 - accuracy: 0.8546 - val_loss: 2.0464 - val_accuracy: 0.2445
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.8589
# Epoch 65: val_loss did not improve from 1.79193
# 1/1 [==============================] - 6s 6s/step - loss: 0.3657 - accuracy: 0.8589 - val_loss: 2.0759 - val_accuracy: 0.2513
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3703 - accuracy: 0.8573
# Epoch 66: val_loss did not improve from 1.79193
# 1/1 [==============================] - 6s 6s/step - loss: 0.3703 - accuracy: 0.8573 - val_loss: 2.0251 - val_accuracy: 0.2393
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3742 - accuracy: 0.8543
# Epoch 67: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3742 - accuracy: 0.8543 - val_loss: 2.0785 - val_accuracy: 0.2421
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.8548
# Epoch 68: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3787 - accuracy: 0.8548 - val_loss: 2.0229 - val_accuracy: 0.2303
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.8568
# Epoch 69: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3707 - accuracy: 0.8568 - val_loss: 2.0502 - val_accuracy: 0.2406
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3823 - accuracy: 0.8510
# Epoch 70: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3823 - accuracy: 0.8510 - val_loss: 2.0970 - val_accuracy: 0.2386
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3693 - accuracy: 0.8571
# Epoch 71: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3693 - accuracy: 0.8571 - val_loss: 2.1577 - val_accuracy: 0.2436
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8600
# Epoch 72: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3637 - accuracy: 0.8600 - val_loss: 2.2041 - val_accuracy: 0.2536
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.8579
# Epoch 73: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3654 - accuracy: 0.8579 - val_loss: 2.1740 - val_accuracy: 0.2433
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3578 - accuracy: 0.8618
# Epoch 74: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3578 - accuracy: 0.8618 - val_loss: 2.1470 - val_accuracy: 0.2489
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3552 - accuracy: 0.8632
# Epoch 75: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3552 - accuracy: 0.8632 - val_loss: 2.2149 - val_accuracy: 0.2494
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8633
# Epoch 76: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3545 - accuracy: 0.8633 - val_loss: 2.1542 - val_accuracy: 0.2462
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.8659
# Epoch 77: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3491 - accuracy: 0.8659 - val_loss: 2.1350 - val_accuracy: 0.2240
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3476 - accuracy: 0.8656
# Epoch 78: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3476 - accuracy: 0.8656 - val_loss: 2.1747 - val_accuracy: 0.2492
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3450 - accuracy: 0.8671
# Epoch 79: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3450 - accuracy: 0.8671 - val_loss: 2.1677 - val_accuracy: 0.2480
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3427 - accuracy: 0.8679
# Epoch 80: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3427 - accuracy: 0.8679 - val_loss: 2.1664 - val_accuracy: 0.2408
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.8698
# Epoch 81: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3385 - accuracy: 0.8698 - val_loss: 2.1901 - val_accuracy: 0.2425
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3387 - accuracy: 0.8688
# Epoch 82: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3387 - accuracy: 0.8688 - val_loss: 2.1716 - val_accuracy: 0.2410
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8699
# Epoch 83: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3368 - accuracy: 0.8699 - val_loss: 2.2124 - val_accuracy: 0.2446
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.8712
# Epoch 84: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3333 - accuracy: 0.8712 - val_loss: 2.2020 - val_accuracy: 0.2464
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8721
# Epoch 85: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3316 - accuracy: 0.8721 - val_loss: 2.1967 - val_accuracy: 0.2441
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3325 - accuracy: 0.8714
# Epoch 86: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3325 - accuracy: 0.8714 - val_loss: 2.2038 - val_accuracy: 0.2384
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8708
# Epoch 87: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3338 - accuracy: 0.8708 - val_loss: 2.2473 - val_accuracy: 0.2340
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8707
# Epoch 88: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3338 - accuracy: 0.8707 - val_loss: 2.2131 - val_accuracy: 0.2327
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.8737
# Epoch 89: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3278 - accuracy: 0.8737 - val_loss: 2.2299 - val_accuracy: 0.2202
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8724
# Epoch 90: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3300 - accuracy: 0.8724 - val_loss: 2.2105 - val_accuracy: 0.2137
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.8737
# Epoch 91: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3249 - accuracy: 0.8737 - val_loss: 2.2652 - val_accuracy: 0.2285
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.8727
# Epoch 92: val_loss did not improve from 1.79193
# 1/1 [==============================] - 4s 4s/step - loss: 0.3304 - accuracy: 0.8727 - val_loss: 2.2399 - val_accuracy: 0.2125
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8735
# Epoch 93: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3266 - accuracy: 0.8735 - val_loss: 2.2880 - val_accuracy: 0.2453
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8753
# Epoch 94: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3232 - accuracy: 0.8753 - val_loss: 2.2516 - val_accuracy: 0.2397
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.8766
# Epoch 95: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3191 - accuracy: 0.8766 - val_loss: 2.2119 - val_accuracy: 0.2090
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.8749
# Epoch 96: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3203 - accuracy: 0.8749 - val_loss: 2.2530 - val_accuracy: 0.2273
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3186 - accuracy: 0.8765
# Epoch 97: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3186 - accuracy: 0.8765 - val_loss: 2.2573 - val_accuracy: 0.2329
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.8787
# Epoch 98: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3134 - accuracy: 0.8787 - val_loss: 2.2962 - val_accuracy: 0.2539
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3115 - accuracy: 0.8797
# Epoch 99: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3115 - accuracy: 0.8797 - val_loss: 2.2960 - val_accuracy: 0.2573
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.8788
# Epoch 100: val_loss did not improve from 1.79193
# 1/1 [==============================] - 5s 5s/step - loss: 0.3124 - accuracy: 0.8788 - val_loss: 2.2445 - val_accuracy: 0.2193
# The best model has been saved in SavedModel format at ../saved_model.

# %% [markdown]
# # After training, plot the loss and accuracy graphs
#
# def plot_training_history(history):
#     # Plot training & validation accuracy values
#     plt.figure(figsize=(12, 6))
#
#     plt.subplot(1, 2, 1)
#     plt.plot(history.history['accuracy'], label='Train Accuracy')
#     plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#     plt.title('Model Accuracy')
#     plt.xlabel('Epoch')
#     plt.ylabel('Accuracy')
#     plt.legend()
#
#     # Plot training & validation loss values
#     plt.subplot(1, 2, 2)
#     plt.plot(history.history['loss'], label='Train Loss')
#     plt.plot(history.history['val_loss'], label='Validation Loss')
#     plt.title('Model Loss')
#     plt.xlabel('Epoch')
#     plt.ylabel('Loss')
#     plt.legend()
#
#     # Save the plot as a PNG file
#     plt.savefig('/path/to/your/training_history.png')
#     plt.show()
#
# # Call the function to plot and save the training history
# plot_training_history(history)
#
# print("Training history plot is saved.")

# %% [markdown]
# Step 4 : Displaying results

# %%
# Normalize the image
def normalize_img(img):
    return img / np.max(img)

# Load a test image and keep the geo-referencing information
def load_test_image(image_path):
    img = tiff.imread(image_path).astype(np.float32)
    img = normalize_img(img)
    img = np.expand_dims(img, axis=0)
    
    # Read the geo-referencing info (e.g., transform and CRS)
    with rasterio.open(image_path) as src:
        transform = src.transform
        crs = src.crs
        
    return img, transform, crs

# Load a test label
def load_test_mask(mask_path):
    mask = tiff.imread(mask_path).astype(np.uint8)
    return mask

# Paths to the test image and test label
test_image_path = '../data/patch/test/images/patch_2.0.tif'  
test_mask_path = '../data/patch/test/labels/patch_2.0.tif'

# Load the saved model (SavedModel format)
saved_model_path = '../saved_model'  # Path to the directory of the SavedModel
model = tf.keras.models.load_model(saved_model_path)

# Load and prepare the test image and test label
test_image, transform, crs = load_test_image(test_image_path)
test_mask = load_test_mask(test_mask_path)
print(f'Shape of test image: {test_image.shape}')
print(f'Shape of test mask: {test_mask.shape}')

# Predict the segmentation of the test image
prediction = model.predict(test_image)
predicted_mask = tf.argmax(prediction, axis=-1)
predicted_mask = tf.squeeze(predicted_mask).numpy()

# Save the predicted mask with geo-referencing
predicted_mask_path = '../data/prediction/predicted_mask.tif'  # Replace with the path where you want to save the predicted mask

# Write the predicted mask using rasterio, preserving the geo-referencing
with rasterio.open(test_image_path) as src:
    meta = src.meta  # Get the metadata (including the transform)
    meta.update(driver='GTiff', dtype=rasterio.uint8, count=1)  # Update the metadata to match the predicted mask's data type and single band count
    
    # Save the predicted mask as a georeferenced TIFF
    with rasterio.open(predicted_mask_path, 'w', **meta) as dst:
        dst.write(predicted_mask, 1)  # Write the predicted mask as the first band

print(f'Predicted mask saved as {predicted_mask_path}')
# Out:
# Shape of test image: (1, 224, 224, 4)
# Shape of test mask: (224, 224)
# 1/1 [==============================] - 1s 547ms/step
# Predicted mask saved as ../data/prediction/predicted_mask.tif

# %% [markdown]
# # Display the test image, the test label, and the predicted mask
# plt.figure(figsize=(15, 5))
#
# plt.subplot(1, 3, 1)
# plt.imshow(test_image[0][:, :, :3])
# plt.title('Test Image (RGB)')
#
# plt.subplot(1, 3, 2)
# plt.imshow(test_mask, cmap='gray')
# plt.title('Test Label')
#
# plt.subplot(1, 3, 3)
# plt.imshow(predicted_mask, cmap='gray')
# plt.title('Predicted Mask')
#
# plt.show()
